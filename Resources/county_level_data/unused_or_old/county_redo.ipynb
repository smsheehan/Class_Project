# %%
import pandas as pd

# %%
coc_fips_df = pd.read_csv('county_coc_source.csv')
coc_fips_df.head(10)
# Out:
#    FIPS    county state  number
# 0  1001   Autauga    AL  AL-507
# 1  1003   Baldwin    AL  AL-501
# 2  1005   Barbour    AL  AL-507
# 3  1007      Bibb    AL  AL-507
# 4  1009    Blount    AL  AL-503
# 5  1011   Bullock    AL  AL-507
# 6  1013    Butler    AL  AL-507
# 7  1015   Calhoun    AL  AL-505
# 8  1017  Chambers    AL  AL-507
# 9  1019  Cherokee    AL  AL-503

# %%
population_county_df = pd.read_csv('county_complete.csv')
population_county_df.head(10)
# Out:
#    fips    state             name   pop2000  pop2010   pop2011   pop2012  \
# 0  1001  Alabama   Autauga County   43671.0    54571   55199.0   54927.0
# 1  1003  Alabama   Baldwin County  140415.0   182265  186534.0  190048.0
# 2  1005  Alabama   Barbour County   29038.0    27457   27351.0   27175.0
# 3  1007  Alabama      Bibb County   20826.0    22915   22745.0   22658.0
# 4  1009  Alabama    Blount County   51024.0    57322   57562.0   57595.0
# 5  1011  Alabama   Bullock County   11714.0    10914   10675.0   10612.0
# 6  1013  Alabama    Butler County   21399.0    20947   20880.0   20688.0
# 7  1015  Alabama   Calhoun County  112249.0   118572  117785.0  117219.0
# 8  1017  Alabama  Chambers County   36583.0    34215   34031.0   34092.0
# 9  1019  Alabama  Cherokee County   23988.0    25989   25993.0   25958.0
#
#     pop2013   pop2014   pop2015  ...  poverty_under_18_2019  \
# 0   54695.0   54864.0   54838.0  ...                   23.2
# ...

# %%
county_coc_fips_df = pd.merge(coc_fips_df, population_county_df, left_on=['FIPS'], right_on=['fips'], how='left')
county_coc_fips_df.head(10)
# Out:
#    FIPS    county state_x  number    fips  state_y             name   pop2000  \
# 0  1001   Autauga      AL  AL-507  1001.0  Alabama   Autauga County   43671.0
# 1  1003   Baldwin      AL  AL-501  1003.0  Alabama   Baldwin County  140415.0
# 2  1005   Barbour      AL  AL-507  1005.0  Alabama   Barbour County   29038.0
# 3  1007      Bibb      AL  AL-507  1007.0  Alabama      Bibb County   20826.0
# 4  1009    Blount      AL  AL-503  1009.0  Alabama    Blount County   51024.0
# 5  1011   Bullock      AL  AL-507  1011.0  Alabama   Bullock County   11714.0
# 6  1013    Butler      AL  AL-507  1013.0  Alabama    Butler County   21399.0
# 7  1015   Calhoun      AL  AL-505  1015.0  Alabama   Calhoun County  112249.0
# 8  1017  Chambers      AL  AL-507  1017.0  Alabama  Chambers County   36583.0
# 9  1019  Cherokee      AL  AL-503  1019.0  Alabama  Cherokee County   23988.0
#
#     pop2010   pop2011  ...  poverty_under_18_2019  two_plus_races_2019  \
# ...

# %%
county_coc_fips_df.to_csv("test_check.csv", index=False)

# %%
#NOTE: Had to completely re-do conversion because old FIPS data was unreliable and left everything off by a few rows.
