# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
import numpy as np

# Import our input dataset
df = pd.read_excel('Percent_Total_Homeless_DroppedColumns_AllCoC.xlsx')
df.head()
# Out:
#    Year  TotalHomeless  Population  Unemployment  Unsheltered_perc_tot  \
# 0  2019           1111      288000           4.4              8.730873
# 1  2018           1094      290521           5.0              8.592322
# 2  2017           1128      294338           5.4             13.741135
# 3  2016           1105      297249           5.3             21.719457
# 4  2015           1208      297547           4.9             14.817881
#
#    TotalBeds_perc_tot  Emergency_perc_tot  Transitional_perc_tot  \
# 0           92.979298           71.917192              21.062106
# 1           93.967093           68.464351              25.502742
# 2           90.691489           52.925532              37.765957
# 3           91.131222           50.045249              41.085973
# 4           84.354305           49.917219              34.437086
#
#    SafeHaven_perc_tot  PermanentSupportive_perc_tot  PermanentOther_perc_tot  \
# 0                 0.0                     54.095410                 6.390639
# 1                 0.0                     55.210238                 6.489945
# 2                 0.0                     50.620567                 6.294326
# 3                 0.0                     39.276018                 8.778281
# 4                 0.0                     40.728477                 5.877483
#
#    RapidRehousing_perc_tot
# 0                15.391539
# 1                11.425960
# 2                 3.812057
# 3                 4.977376
# 4                 2.317881

# %%
#df["SafeHaven_perc_tot"] = df["SafeHaven_perc_tot"].astype(bool).astype(int)

# %%
df = df.drop(['TotalHomeless', 'Population', 'Year', 'TotalBeds_perc_tot', 'Unemployment' ], axis=1)
df.head()
# Out:
#    Unsheltered_perc_tot  Emergency_perc_tot  Transitional_perc_tot  \
# 0              8.730873           71.917192              21.062106
# 1              8.592322           68.464351              25.502742
# 2             13.741135           52.925532              37.765957
# 3             21.719457           50.045249              41.085973
# 4             14.817881           49.917219              34.437086
#
#    SafeHaven_perc_tot  PermanentSupportive_perc_tot  PermanentOther_perc_tot  \
# 0                 0.0                     54.095410                 6.390639
# 1                 0.0                     55.210238                 6.489945
# 2                 0.0                     50.620567                 6.294326
# 3                 0.0                     39.276018                 8.778281
# 4                 0.0                     40.728477                 5.877483
#
#    RapidRehousing_perc_tot
# 0                15.391539
# 1                11.425960
# 2                 3.812057
# 3                 4.977376
# 4                 2.317881

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unsheltered_perc_tot          2199 non-null   float64
#  1   Emergency_perc_tot            2199 non-null   float64
#  2   Transitional_perc_tot         2199 non-null   float64
#  3   SafeHaven_perc_tot            2199 non-null   float64
#  4   PermanentSupportive_perc_tot  2199 non-null   float64
#  5   PermanentOther_perc_tot       2199 non-null   float64
#  6   RapidRehousing_perc_tot       2199 non-null   float64
# dtypes: float64(7)
# memory usage: 120.4 KB

# %%
df.head()
# Out:
#    Unsheltered_perc_tot  Emergency_perc_tot  Transitional_perc_tot  \
# 0              8.730873           71.917192              21.062106
# 1              8.592322           68.464351              25.502742
# 2             13.741135           52.925532              37.765957
# 3             21.719457           50.045249              41.085973
# 4             14.817881           49.917219              34.437086
#
#    SafeHaven_perc_tot  PermanentSupportive_perc_tot  PermanentOther_perc_tot  \
# 0                 0.0                     54.095410                 6.390639
# 1                 0.0                     55.210238                 6.489945
# 2                 0.0                     50.620567                 6.294326
# 3                 0.0                     39.276018                 8.778281
# 4                 0.0                     40.728477                 5.877483
#
#    RapidRehousing_perc_tot
# 0                15.391539
# 1                11.425960
# 2                 3.812057
# 3                 4.977376
# 4                 2.317881

# %%
#q = df['Unsheltered_perc_tot'].quantile(np.arange(10) / 10)

# %%
#df['UnshelteredPercentQuantile'] = df['Unsheltered_perc_tot'].apply(lambda x : q.index[np.searchsorted(q, x, side='right')-1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unsheltered_perc_tot          2199 non-null   float64
#  1   Emergency_perc_tot            2199 non-null   float64
#  2   Transitional_perc_tot         2199 non-null   float64
#  3   SafeHaven_perc_tot            2199 non-null   float64
#  4   PermanentSupportive_perc_tot  2199 non-null   float64
#  5   PermanentOther_perc_tot       2199 non-null   float64
#  6   RapidRehousing_perc_tot       2199 non-null   float64
# dtypes: float64(7)
# memory usage: 120.4 KB

# %%
pd.cut(df['Unsheltered_perc_tot'], bins=4).value_counts()
# Out:
# (-0.0961, 24.024]    1299
# (24.024, 48.049]      482
# (48.049, 72.073]      307
# (72.073, 96.098]      111
# Name: Unsheltered_perc_tot, dtype: int64

# %%
size_bins=[-1, 25, 48, 72, 100]
group_names = ["0", "1", "2", "3"]

# %%
df['Unshelteredtwentythreshold'] = pd.cut(df['Unsheltered_perc_tot'], size_bins, labels=group_names)

# %%
df['Unshelteredtwentythreshold'] = df['Unshelteredtwentythreshold'].astype(int)

# %%
df=df.drop('Unsheltered_perc_tot', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Emergency_perc_tot            2199 non-null   float64
#  1   Transitional_perc_tot         2199 non-null   float64
#  2   SafeHaven_perc_tot            2199 non-null   float64
#  3   PermanentSupportive_perc_tot  2199 non-null   float64
#  4   PermanentOther_perc_tot       2199 non-null   float64
#  5   RapidRehousing_perc_tot       2199 non-null   float64
#  6   Unshelteredtwentythreshold    2199 non-null   int32
# dtypes: float64(6), int32(1)
# memory usage: 111.8 KB

# %%
# Remove outcome target from features data
y = df.Unshelteredtwentythreshold.values
X = df.drop(columns="Unshelteredtwentythreshold").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

# %%
# # Preprocess numerical data for neural network

# # Create a StandardScaler instances
# scaler = StandardScaler()

# # Fit the StandardScaler
# X_scaler = scaler.fit(X_train)

# # Scale the data
# X_train_scaled = X_scaler.transform(X_train)
# X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=64, activation="sigmoid", input_dim=6))
nn_model.add(tf.keras.layers.Dense(units=32, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 52/52 [==============================] - 1s 2ms/step - loss: 0.6240 - accuracy: 0.2377
# Epoch 2/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5254 - accuracy: 0.3038
# Epoch 3/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.4351 - accuracy: 0.3323
# Epoch 4/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3289 - accuracy: 0.3905
# Epoch 5/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.1024 - accuracy: 0.4154
# Epoch 6/100
# 52/52 [==============================] - 0s 2ms/step - loss: -0.2066 - accuracy: 0.4767
# Epoch 7/100
# 52/52 [==============================] - 0s 2ms/step - loss: -0.6580 - accuracy: 0.4888
# Epoch 8/100
# 52/52 [==============================] - 0s 2ms/step - loss: -
# Epoch 63/100
# 52/52 [==============================] - 0s 2ms/step - loss: -766.1588 - accuracy: 0.5579
# Epoch 64/100
# 52/52 [==============================] - 0s 2ms/step - loss: -795.9927 - accuracy: 0.5622
# Epoch 65/100
# 52/52 [==============================] - 0s 2ms/step - loss: -823.6318 - accuracy: 0.5628
# Epoch 66/100
# 52/52 [==============================] - 0s 2ms/step - loss: -857.8900 - accuracy: 0.5670
# Epoch 67/100
# 52/52 [==============================] - 0s 2ms/step - loss: -883.9891 - accuracy: 0.5597
# Epoch 68/100
# 52/52 [==============================] - 0s 2ms/step - loss: -916.6962 - accuracy: 0.5682
# Epoch 69/100
# 52/52 [==============================] - 0s 2ms/step - loss: -947.7924 - accuracy: 0.5694
# Epoch 70/100
# 52/52 [==============================] - 0s 2ms/step - loss: -977.6232 - accuracy: 0.5567
# Epoch 71/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1009.2634 - accuracy: 0.5670
# Epoch 72/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1048.8607 - accuracy: 0.5591
# Epoch 73/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1080.4645 - accuracy: 0.5670
# Epoch 74/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1116.5005 - accuracy: 0.5603
# Epoch 75/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1151.5889 - accuracy: 0.5682
# Epoch 76/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1181.2660 - accuracy: 0.5743
# Epoch 77/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1220.9200 - accuracy: 0.5537
# Epoch 78/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1254.8018 - accuracy: 0.5694
# Epoch 79/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1292.4719 - accuracy: 0.5652
# Epoch 80/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1333.3185 - accuracy: 0.5670
# Epoch 81/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1371.8444 - accuracy: 0.5670
# Epoch 82/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1408.6593 - accuracy: 0.5670
# Epoch 83/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1437.5299 - accuracy: 0.5652
# Epoch 84/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1482.3467 - accuracy: 0.5658
# Epoch 85/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1523.0750 - accuracy: 0.5725
# Epoch 86/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1564.8893 - accuracy: 0.5652
# Epoch 87/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1609.4812 - accuracy: 0.5676
# Epoch 88/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1645.2717 - accuracy: 0.5634
# Epoch 89/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1689.4463 - accuracy: 0.5646
# Epoch 90/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1721.8773 - accuracy: 0.5713
# Epoch 91/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1777.8895 - accuracy: 0.5609
# Epoch 92/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1811.7775 - accuracy: 0.5694
# Epoch 93/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1860.3613 - accuracy: 0.5658
# Epoch 94/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1903.0625 - accuracy: 0.5658
# Epoch 95/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1935.4224 - accuracy: 0.5761
# Epoch 96/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1989.9073 - accuracy: 0.5664
# Epoch 97/100
# 52/52 [==============================] - 0s 2ms/step - loss: -2037.3423 - accuracy: 0.5713
# Epoch 98/100
# 52/52 [==============================] - 0s 2ms/step - loss: -2075.4072 - accuracy: 0.5664
# Epoch 99/100
# 52/52 [==============================] - 0s 2ms/step - loss: -2129.5837 - accuracy: 0.5688
# Epoch 100/100
# 52/52 [==============================] - 0s 2ms/step - loss: -2140.9871 - accuracy: 0.5773
# 18/18 - 0s - loss: -2.2155e+03 - accuracy: 0.5891 - 150ms/epoch - 8ms/step
# Loss: -2215.471923828125, Accuracy: 0.589090883731842
