# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
import numpy as np

# Import our input dataset
df = pd.read_excel('Percent_Total_Homeless_DroppedColumns_AllCoC.xlsx')
df.head()
# Out:
#    Year  TotalHomeless  Population  Unemployment  Unsheltered_perc_tot  \
# 0  2019           1111      288000           4.4              8.730873
# 1  2018           1094      290521           5.0              8.592322
# 2  2017           1128      294338           5.4             13.741135
# 3  2016           1105      297249           5.3             21.719457
# 4  2015           1208      297547           4.9             14.817881
#
#    TotalBeds_perc_tot  Emergency_perc_tot  Transitional_perc_tot  \
# 0           92.979298           71.917192              21.062106
# 1           93.967093           68.464351              25.502742
# 2           90.691489           52.925532              37.765957
# 3           91.131222           50.045249              41.085973
# 4           84.354305           49.917219              34.437086
#
#    SafeHaven_perc_tot  PermanentSupportive_perc_tot  PermanentOther_perc_tot  \
# 0                 0.0                     54.095410                 6.390639
# 1                 0.0                     55.210238                 6.489945
# 2                 0.0                     50.620567                 6.294326
# 3                 0.0                     39.276018                 8.778281
# 4                 0.0                     40.728477                 5.877483
#
#    RapidRehousing_perc_tot
# 0                15.391539
# 1                11.425960
# 2                 3.812057
# 3                 4.977376
# 4                 2.317881

# %%
#df["SafeHaven_perc_tot"] = df["SafeHaven_perc_tot"].astype(bool).astype(int)

# %%
df = df.drop(['TotalHomeless', 'Population', 'Year' ], axis=1)
df.head()
# Out:
#    Unemployment  Unsheltered_perc_tot  TotalBeds_perc_tot  Emergency_perc_tot  \
# 0           4.4              8.730873           92.979298           71.917192
# 1           5.0              8.592322           93.967093           68.464351
# 2           5.4             13.741135           90.691489           52.925532
# 3           5.3             21.719457           91.131222           50.045249
# 4           4.9             14.817881           84.354305           49.917219
#
#    Transitional_perc_tot  SafeHaven_perc_tot  PermanentSupportive_perc_tot  \
# 0              21.062106                 0.0                     54.095410
# 1              25.502742                 0.0                     55.210238
# 2              37.765957                 0.0                     50.620567
# 3              41.085973                 0.0                     39.276018
# 4              34.437086                 0.0                     40.728477
#
#    PermanentOther_perc_tot  RapidRehousing_perc_tot
# 0                 6.390639                15.391539
# 1                 6.489945                11.425960
# 2                 6.294326                 3.812057
# 3                 8.778281                 4.977376
# 4                 5.877483                 2.317881

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unemployment                  2199 non-null   float64
#  1   Unsheltered_perc_tot          2199 non-null   float64
#  2   TotalBeds_perc_tot            2199 non-null   float64
#  3   Emergency_perc_tot            2199 non-null   float64
#  4   Transitional_perc_tot         2199 non-null   float64
#  5   SafeHaven_perc_tot            2199 non-null   float64
#  6   PermanentSupportive_perc_tot  2199 non-null   float64
#  7   PermanentOther_perc_tot       2199 non-null   float64
#  8   RapidRehousing_perc_tot       2199 non-null   float64
# dtypes: float64(9)
# memory usage: 154.7 KB

# %%
df.head()
# Out:
#    Unemployment  Unsheltered_perc_tot  TotalBeds_perc_tot  Emergency_perc_tot  \
# 0           4.4              8.730873           92.979298           71.917192
# 1           5.0              8.592322           93.967093           68.464351
# 2           5.4             13.741135           90.691489           52.925532
# 3           5.3             21.719457           91.131222           50.045249
# 4           4.9             14.817881           84.354305           49.917219
#
#    Transitional_perc_tot  SafeHaven_perc_tot  PermanentSupportive_perc_tot  \
# 0              21.062106                 0.0                     54.095410
# 1              25.502742                 0.0                     55.210238
# 2              37.765957                 0.0                     50.620567
# 3              41.085973                 0.0                     39.276018
# 4              34.437086                 0.0                     40.728477
#
#    PermanentOther_perc_tot  RapidRehousing_perc_tot
# 0                 6.390639                15.391539
# 1                 6.489945                11.425960
# 2                 6.294326                 3.812057
# 3                 8.778281                 4.977376
# 4                 5.877483                 2.317881

# %%
#q = df['Unsheltered_perc_tot'].quantile(np.arange(10) / 10)

# %%
#df['UnshelteredPercentQuantile'] = df['Unsheltered_perc_tot'].apply(lambda x : q.index[np.searchsorted(q, x, side='right')-1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unemployment                  2199 non-null   float64
#  1   Unsheltered_perc_tot          2199 non-null   float64
#  2   TotalBeds_perc_tot            2199 non-null   float64
#  3   Emergency_perc_tot            2199 non-null   float64
#  4   Transitional_perc_tot         2199 non-null   float64
#  5   SafeHaven_perc_tot            2199 non-null   float64
#  6   PermanentSupportive_perc_tot  2199 non-null   float64
#  7   PermanentOther_perc_tot       2199 non-null   float64
#  8   RapidRehousing_perc_tot       2199 non-null   float64
# dtypes: float64(9)
# memory usage: 154.7 KB

# %%
pd.cut(df['Unsheltered_perc_tot'], bins=3).value_counts()
# Out:
# (-0.0961, 32.033]    1500
# (32.033, 64.065]      484
# (64.065, 96.098]      215
# Name: Unsheltered_perc_tot, dtype: int64

# %%
size_bins=[-1, 33, 66, 100]
group_names = ["0", "1", "2"]

# %%
df['Unshelteredtwentythreshold'] = pd.cut(df['Unsheltered_perc_tot'], size_bins, labels=group_names)

# %%
df['Unshelteredtwentythreshold'] = df['Unshelteredtwentythreshold'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unemployment                  2199 non-null   float64
#  1   Unsheltered_perc_tot          2199 non-null   float64
#  2   TotalBeds_perc_tot            2199 non-null   float64
#  3   Emergency_perc_tot            2199 non-null   float64
#  4   Transitional_perc_tot         2199 non-null   float64
#  5   SafeHaven_perc_tot            2199 non-null   float64
#  6   PermanentSupportive_perc_tot  2199 non-null   float64
#  7   PermanentOther_perc_tot       2199 non-null   float64
#  8   RapidRehousing_perc_tot       2199 non-null   float64
#  9   Unshelteredtwentythreshold    2199 non-null   int32
# dtypes: float64(9), int32(1)
# memory usage: 163.3 KB

# %%
# Remove outcome target from features data
y = df.Unshelteredtwentythreshold.values
X = df.drop(columns="Unshelteredtwentythreshold").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

# %%
# # Preprocess numerical data for neural network

# # Create a StandardScaler instances
# scaler = StandardScaler()

# # Fit the StandardScaler
# X_scaler = scaler.fit(X_train)

# # Scale the data
# X_train_scaled = X_scaler.transform(X_train)
# X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=64, activation="sigmoid", input_dim=9))
nn_model.add(tf.keras.layers.Dense(units=32, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.1768 - accuracy: 0.8023
# Epoch 2/100
# 52/52 [==============================] - 0s 2ms/step - loss: -0.5003 - accuracy: 0.8623
# Epoch 3/100
# 52/52 [==============================] - 0s 2ms/step - loss: -
# Epoch 64/100
# 52/52 [==============================] - 0s 2ms/step - loss: -669.9097 - accuracy: 0.8702
# Epoch 65/100
# 52/52 [==============================] - 0s 1ms/step - loss: -688.6674 - accuracy: 0.8830
# Epoch 66/100
# 52/52 [==============================] - 0s 1ms/step - loss: -708.2075 - accuracy: 0.8805
# Epoch 67/100
# 52/52 [==============================] - 0s 1ms/step - loss: -727.8691 - accuracy: 0.8781
# Epoch 68/100
# 52/52 [==============================] - 0s 1ms/step - loss: -747.0911 - accuracy: 0.8672
# Epoch 69/100
# 52/52 [==============================] - 0s 1ms/step - loss: -766.3203 - accuracy: 0.8811
# Epoch 70/100
# 52/52 [==============================] - 0s 1ms/step - loss: -786.0847 - accuracy: 0.8702
# Epoch 71/100
# 52/52 [==============================] - 0s 1ms/step - loss: -806.0580 - accuracy: 0.8836
# Epoch 72/100
# 52/52 [==============================] - 0s 1ms/step - loss: -826.4406 - accuracy: 0.8793
# Epoch 73/100
# 52/52 [==============================] - 0s 1ms/step - loss: -846.9568 - accuracy: 0.8811
# Epoch 74/100
# 52/52 [==============================] - 0s 1ms/step - loss: -867.4866 - accuracy: 0.8763
# Epoch 75/100
# 52/52 [==============================] - 0s 1ms/step - loss: -888.1667 - accuracy: 0.8775
# Epoch 76/100
# 52/52 [==============================] - 0s 1ms/step - loss: -909.5814 - accuracy: 0.8799
# Epoch 77/100
# 52/52 [==============================] - 0s 1ms/step - loss: -930.8596 - accuracy: 0.8763
# Epoch 78/100
# 52/52 [==============================] - 0s 1ms/step - loss: -952.3925 - accuracy: 0.8781
# Epoch 79/100
# 52/52 [==============================] - 0s 1ms/step - loss: -974.2172 - accuracy: 0.8751
# Epoch 80/100
# 52/52 [==============================] - 0s 1ms/step - loss: -996.0179 - accuracy: 0.8769
# Epoch 81/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1018.0056 - accuracy: 0.8745
# Epoch 82/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1040.0739 - accuracy: 0.8817
# Epoch 83/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1062.3680 - accuracy: 0.8745
# Epoch 84/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1084.8209 - accuracy: 0.8769
# Epoch 85/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1107.2852 - accuracy: 0.8781
# Epoch 86/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1130.2241 - accuracy: 0.8793
# Epoch 87/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1153.3893 - accuracy: 0.8727
# Epoch 88/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1177.0923 - accuracy: 0.8793
# Epoch 89/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1201.3137 - accuracy: 0.8824
# Epoch 90/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1224.7583 - accuracy: 0.8781
# Epoch 91/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1248.5157 - accuracy: 0.8751
# Epoch 92/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1273.2731 - accuracy: 0.8817
# Epoch 93/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1296.9337 - accuracy: 0.8757
# Epoch 94/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1322.0181 - accuracy: 0.8811
# Epoch 95/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1346.4788 - accuracy: 0.8793
# Epoch 96/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1372.1471 - accuracy: 0.8824
# Epoch 97/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1397.2839 - accuracy: 0.8860
# Epoch 98/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1422.5621 - accuracy: 0.8787
# Epoch 99/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1448.2207 - accuracy: 0.8763
# Epoch 100/100
# 52/52 [==============================] - 0s 2ms/step - loss: -1474.1215 - accuracy: 0.8878
# 18/18 - 0s - loss: -1.4672e+03 - accuracy: 0.8727 - 148ms/epoch - 8ms/step
# Loss: -1467.189453125, Accuracy: 0.8727272748947144
