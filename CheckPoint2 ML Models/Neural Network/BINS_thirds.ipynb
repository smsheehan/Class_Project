# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
import numpy as np

# Import our input dataset
df = pd.read_excel('Percent_Total_Homeless_DroppedColumns_AllCoC.xlsx')
df.head()
# Out:
#    Year  TotalHomeless  Population  Unemployment  Unsheltered_perc_tot  \
# 0  2019           1111      288000           4.4              8.730873
# 1  2018           1094      290521           5.0              8.592322
# 2  2017           1128      294338           5.4             13.741135
# 3  2016           1105      297249           5.3             21.719457
# 4  2015           1208      297547           4.9             14.817881
#
#    TotalBeds_perc_tot  Emergency_perc_tot  Transitional_perc_tot  \
# 0           92.979298           71.917192              21.062106
# 1           93.967093           68.464351              25.502742
# 2           90.691489           52.925532              37.765957
# 3           91.131222           50.045249              41.085973
# 4           84.354305           49.917219              34.437086
#
#    SafeHaven_perc_tot  PermanentSupportive_perc_tot  PermanentOther_perc_tot  \
# 0                 0.0                     54.095410                 6.390639
# 1                 0.0                     55.210238                 6.489945
# 2                 0.0                     50.620567                 6.294326
# 3                 0.0                     39.276018                 8.778281
# 4                 0.0                     40.728477                 5.877483
#
#    RapidRehousing_perc_tot
# 0                15.391539
# 1                11.425960
# 2                 3.812057
# 3                 4.977376
# 4                 2.317881

# %%
#df["SafeHaven_perc_tot"] = df["SafeHaven_perc_tot"].astype(bool).astype(int)

# %%
df = df.drop([ 'Year' ], axis=1)
df.head()
# Out:
#    TotalHomeless  Population  Unemployment  Unsheltered_perc_tot  \
# 0           1111      288000           4.4              8.730873
# 1           1094      290521           5.0              8.592322
# 2           1128      294338           5.4             13.741135
# 3           1105      297249           5.3             21.719457
# 4           1208      297547           4.9             14.817881
#
#    TotalBeds_perc_tot  Emergency_perc_tot  Transitional_perc_tot  \
# 0           92.979298           71.917192              21.062106
# 1           93.967093           68.464351              25.502742
# 2           90.691489           52.925532              37.765957
# 3           91.131222           50.045249              41.085973
# 4           84.354305           49.917219              34.437086
#
#    SafeHaven_perc_tot  PermanentSupportive_perc_tot  PermanentOther_perc_tot  \
# 0                 0.0                     54.095410                 6.390639
# 1                 0.0                     55.210238                 6.489945
# 2                 0.0                     50.620567                 6.294326
# 3                 0.0                     39.276018                 8.778281
# 4                 0.0                     40.728477                 5.877483
#
#    RapidRehousing_perc_tot
# 0                15.391539
# 1                11.425960
# 2                 3.812057
# 3                 4.977376
# 4                 2.317881

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   TotalHomeless                 2199 non-null   int64
#  1   Population                    2199 non-null   int64
#  2   Unemployment                  2199 non-null   float64
#  3   Unsheltered_perc_tot          2199 non-null   float64
#  4   TotalBeds_perc_tot            2199 non-null   float64
#  5   Emergency_perc_tot            2199 non-null   float64
#  6   Transitional_perc_tot         2199 non-null   float64
#  7   SafeHaven_perc_tot            2199 non-null   float64
#  8   PermanentSupportive_perc_tot  2199 non-null   float64
#  9   PermanentOther_perc_tot       2199 non-null   float64
#  10  RapidRehousing_perc_tot       2199 non-null   float64
# dtypes: float64(9), int64(2)
# memory usage: 189.1 KB

# %%
df.head()
# Out:
#    TotalHomeless  Population  Unemployment  Unsheltered_perc_tot  \
# 0           1111      288000           4.4              8.730873
# 1           1094      290521           5.0              8.592322
# 2           1128      294338           5.4             13.741135
# 3           1105      297249           5.3             21.719457
# 4           1208      297547           4.9             14.817881
#
#    TotalBeds_perc_tot  Emergency_perc_tot  Transitional_perc_tot  \
# 0           92.979298           71.917192              21.062106
# 1           93.967093           68.464351              25.502742
# 2           90.691489           52.925532              37.765957
# 3           91.131222           50.045249              41.085973
# 4           84.354305           49.917219              34.437086
#
#    SafeHaven_perc_tot  PermanentSupportive_perc_tot  PermanentOther_perc_tot  \
# 0                 0.0                     54.095410                 6.390639
# 1                 0.0                     55.210238                 6.489945
# 2                 0.0                     50.620567                 6.294326
# 3                 0.0                     39.276018                 8.778281
# 4                 0.0                     40.728477                 5.877483
#
#    RapidRehousing_perc_tot
# 0                15.391539
# 1                11.425960
# 2                 3.812057
# 3                 4.977376
# 4                 2.317881

# %%
#q = df['Unsheltered_perc_tot'].quantile(np.arange(10) / 10)

# %%
#df['UnshelteredPercentQuantile'] = df['Unsheltered_perc_tot'].apply(lambda x : q.index[np.searchsorted(q, x, side='right')-1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   TotalHomeless                 2199 non-null   int64
#  1   Population                    2199 non-null   int64
#  2   Unemployment                  2199 non-null   float64
#  3   Unsheltered_perc_tot          2199 non-null   float64
#  4   TotalBeds_perc_tot            2199 non-null   float64
#  5   Emergency_perc_tot            2199 non-null   float64
#  6   Transitional_perc_tot         2199 non-null   float64
#  7   SafeHaven_perc_tot            2199 non-null   float64
#  8   PermanentSupportive_perc_tot  2199 non-null   float64
#  9   PermanentOther_perc_tot       2199 non-null   float64
#  10  RapidRehousing_perc_tot       2199 non-null   float64
# dtypes: float64(9), int64(2)
# memory usage: 189.1 KB

# %%
pd.cut(df['Unsheltered_perc_tot'], bins=3).value_counts()
# Out:
# (-0.0961, 32.033]    1500
# (32.033, 64.065]      484
# (64.065, 96.098]      215
# Name: Unsheltered_perc_tot, dtype: int64

# %%
size_bins=[-1, 33, 66, 100]
group_names = ["0", "1", "2"]

# %%
df['Unshelteredtwentythreshold'] = pd.cut(df['Unsheltered_perc_tot'], size_bins, labels=group_names)

# %%
df['Unshelteredtwentythreshold'] = df['Unshelteredtwentythreshold'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   TotalHomeless                 2199 non-null   int64
#  1   Population                    2199 non-null   int64
#  2   Unemployment                  2199 non-null   float64
#  3   Unsheltered_perc_tot          2199 non-null   float64
#  4   TotalBeds_perc_tot            2199 non-null   float64
#  5   Emergency_perc_tot            2199 non-null   float64
#  6   Transitional_perc_tot         2199 non-null   float64
#  7   SafeHaven_perc_tot            2199 non-null   float64
#  8   PermanentSupportive_perc_tot  2199 non-null   float64
#  9   PermanentOther_perc_tot       2199 non-null   float64
#  10  RapidRehousing_perc_tot       2199 non-null   float64
#  11  Unshelteredtwentythreshold    2199 non-null   int32
# dtypes: float64(9), int32(1), int64(2)
# memory usage: 197.7 KB

# %%
# Remove outcome target from features data
y = df.Unshelteredtwentythreshold.values
X = df.drop(columns="Unshelteredtwentythreshold").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
from keras.utils import to_categorical

nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=64, activation="sigmoid", input_dim=11))
nn_model.add(tf.keras.layers.Dense(units=32, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
y_train = to_categorical(y_train)
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32/648673466.py in <module>
#       1 # Define the deep learning model
# ----> 2 from keras.utils import to_categorical
#       3
#       4 nn_model = tf.keras.models.Sequential()
#       5 nn_model.add(tf.keras.layers.Dense(units=64, activation="sigmoid", input_dim=11))
#
# ImportError: cannot import name 'to_categorical' from 'keras.utils' (C:\Users\smshe\anaconda3\envs\mlenv\lib\site-packages\keras\utils\__init__.py)
