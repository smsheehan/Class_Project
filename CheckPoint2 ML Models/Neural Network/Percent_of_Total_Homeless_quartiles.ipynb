# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
import numpy as np

# Import our input dataset
df = pd.read_excel('Percent_Total_Homeless_DroppedColumns_AllCoC.xlsx')
df.head()
# Out:
#    Year  TotalHomeless  Population  Unemployment  Unsheltered_perc_tot  \
# 0  2019           1111      288000           4.4              8.730873
# 1  2018           1094      290521           5.0              8.592322
# 2  2017           1128      294338           5.4             13.741135
# 3  2016           1105      297249           5.3             21.719457
# 4  2015           1208      297547           4.9             14.817881
#
#    TotalBeds_perc_tot  Emergency_perc_tot  Transitional_perc_tot  \
# 0           92.979298           71.917192              21.062106
# 1           93.967093           68.464351              25.502742
# 2           90.691489           52.925532              37.765957
# 3           91.131222           50.045249              41.085973
# 4           84.354305           49.917219              34.437086
#
#    SafeHaven_perc_tot  PermanentSupportive_perc_tot  PermanentOther_perc_tot  \
# 0                 0.0                     54.095410                 6.390639
# 1                 0.0                     55.210238                 6.489945
# 2                 0.0                     50.620567                 6.294326
# 3                 0.0                     39.276018                 8.778281
# 4                 0.0                     40.728477                 5.877483
#
#    RapidRehousing_perc_tot
# 0                15.391539
# 1                11.425960
# 2                 3.812057
# 3                 4.977376
# 4                 2.317881

# %%
#df["SafeHaven_perc_tot"] = df["SafeHaven_perc_tot"].astype(bool).astype(int)

# %%
df = df.drop(['TotalHomeless', 'Population', 'Year' ], axis=1)
df.head()
# Out:
#    Unemployment  Unsheltered_perc_tot  TotalBeds_perc_tot  Emergency_perc_tot  \
# 0           4.4              8.730873           92.979298           71.917192
# 1           5.0              8.592322           93.967093           68.464351
# 2           5.4             13.741135           90.691489           52.925532
# 3           5.3             21.719457           91.131222           50.045249
# 4           4.9             14.817881           84.354305           49.917219
#
#    Transitional_perc_tot  SafeHaven_perc_tot  PermanentSupportive_perc_tot  \
# 0              21.062106                 0.0                     54.095410
# 1              25.502742                 0.0                     55.210238
# 2              37.765957                 0.0                     50.620567
# 3              41.085973                 0.0                     39.276018
# 4              34.437086                 0.0                     40.728477
#
#    PermanentOther_perc_tot  RapidRehousing_perc_tot
# 0                 6.390639                15.391539
# 1                 6.489945                11.425960
# 2                 6.294326                 3.812057
# 3                 8.778281                 4.977376
# 4                 5.877483                 2.317881

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unemployment                  2199 non-null   float64
#  1   Unsheltered_perc_tot          2199 non-null   float64
#  2   TotalBeds_perc_tot            2199 non-null   float64
#  3   Emergency_perc_tot            2199 non-null   float64
#  4   Transitional_perc_tot         2199 non-null   float64
#  5   SafeHaven_perc_tot            2199 non-null   float64
#  6   PermanentSupportive_perc_tot  2199 non-null   float64
#  7   PermanentOther_perc_tot       2199 non-null   float64
#  8   RapidRehousing_perc_tot       2199 non-null   float64
# dtypes: float64(9)
# memory usage: 154.7 KB

# %%
df.head()
# Out:
#    Unemployment  Unsheltered_perc_tot  TotalBeds_perc_tot  Emergency_perc_tot  \
# 0           4.4              8.730873           92.979298           71.917192
# 1           5.0              8.592322           93.967093           68.464351
# 2           5.4             13.741135           90.691489           52.925532
# 3           5.3             21.719457           91.131222           50.045249
# 4           4.9             14.817881           84.354305           49.917219
#
#    Transitional_perc_tot  SafeHaven_perc_tot  PermanentSupportive_perc_tot  \
# 0              21.062106                 0.0                     54.095410
# 1              25.502742                 0.0                     55.210238
# 2              37.765957                 0.0                     50.620567
# 3              41.085973                 0.0                     39.276018
# 4              34.437086                 0.0                     40.728477
#
#    PermanentOther_perc_tot  RapidRehousing_perc_tot
# 0                 6.390639                15.391539
# 1                 6.489945                11.425960
# 2                 6.294326                 3.812057
# 3                 8.778281                 4.977376
# 4                 5.877483                 2.317881

# %%
#q = df['Unsheltered_perc_tot'].quantile(np.arange(10) / 10)

# %%
#df['UnshelteredPercentQuantile'] = df['Unsheltered_perc_tot'].apply(lambda x : q.index[np.searchsorted(q, x, side='right')-1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unemployment                  2199 non-null   float64
#  1   Unsheltered_perc_tot          2199 non-null   float64
#  2   TotalBeds_perc_tot            2199 non-null   float64
#  3   Emergency_perc_tot            2199 non-null   float64
#  4   Transitional_perc_tot         2199 non-null   float64
#  5   SafeHaven_perc_tot            2199 non-null   float64
#  6   PermanentSupportive_perc_tot  2199 non-null   float64
#  7   PermanentOther_perc_tot       2199 non-null   float64
#  8   RapidRehousing_perc_tot       2199 non-null   float64
# dtypes: float64(9)
# memory usage: 154.7 KB

# %%
pd.cut(df['Unsheltered_perc_tot'], bins=4).value_counts()
# Out:
# (-0.0961, 24.024]    1299
# (24.024, 48.049]      482
# (48.049, 72.073]      307
# (72.073, 96.098]      111
# Name: Unsheltered_perc_tot, dtype: int64

# %%
size_bins=[-1, 25, 48, 72, 100]
group_names = ["0", "1", "2", "3"]

# %%
df['Unshelteredtwentythreshold'] = pd.cut(df['Unsheltered_perc_tot'], size_bins, labels=group_names)

# %%
df['Unshelteredtwentythreshold'] = df['Unshelteredtwentythreshold'].astype(int)

# %%
df=df.drop('Unsheltered_perc_tot', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unemployment                  2199 non-null   float64
#  1   TotalBeds_perc_tot            2199 non-null   float64
#  2   Emergency_perc_tot            2199 non-null   float64
#  3   Transitional_perc_tot         2199 non-null   float64
#  4   SafeHaven_perc_tot            2199 non-null   float64
#  5   PermanentSupportive_perc_tot  2199 non-null   float64
#  6   PermanentOther_perc_tot       2199 non-null   float64
#  7   RapidRehousing_perc_tot       2199 non-null   float64
#  8   Unshelteredtwentythreshold    2199 non-null   int32
# dtypes: float64(8), int32(1)
# memory usage: 146.2 KB

# %%
# Remove outcome target from features data
y = df.Unshelteredtwentythreshold.values
X = df.drop(columns="Unshelteredtwentythreshold").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=64, activation="sigmoid", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=32, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.4094 - accuracy: 0.2717
# Epoch 2/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.0741 - accuracy: 0.4942
# Epoch 3/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.7055 - accuracy: 0.5367
# Epoch 4/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1.6027 - accuracy: 0.5440
# Epoch 5/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2.8758 - accuracy: 0.5452
# Epoch 6/100
# 52/52 [==============================] - 0s 1ms/step - loss: -4.6161 - accuracy: 0.5616
# Epoch 7/100
# 52/52 [==============================] - 0s 1ms/step - loss: -6.8986 - accuracy: 0.5622
# Epoch 8/100
# 52/52 [==============================] - 0s 1ms/step - loss: -9.8165 - accuracy: 0.5609
# Epoch 9/100
# 52/52 [==============================] - 0s 1ms/step - loss: -13.3881 - accuracy: 0.5676
# Epoch 10/100
# 52/52 [==============================] - 0s 1ms/step - loss: -17.8375 - accuracy: 0.5737
# Epoch 11/100
# 52/52 [==============================] - 0s 1ms/step - loss: -22.9106 - accuracy: 0.5700
# Epoch 12/100
# 52/52 [==============================] - 0s 1ms/step - loss: -28.9990 - accuracy: 0.5804
# Epoch 13/100
# 52/52 [==============================] - 0s 1ms/step - loss: -35.7150 - accuracy: 0.5876
# Epoch 14/100
# 52/52 [==============================] - 0s 1ms/step - loss: -43.3658 - accuracy: 0.5828
# Epoch 15/100
# 52/52 [==============================] - 0s 1ms/step - loss: -51.6602 - accuracy: 0.5931
# 52/52 [==============================] - 0s 1ms/step - loss: -749.5016 - accuracy: 0.6198
# Epoch 49/100
# 52/52 [==============================] - 0s 1ms/step - loss: -780.7119 - accuracy: 0.6204
# Epoch 50/100
# 52/52 [==============================] - 0s 1ms/step - loss: -812.4045 - accuracy: 0.6198
# Epoch 51/100
# 52/52 [==============================] - 0s 1ms/step - loss: -844.2850 - accuracy: 0.6222
# Epoch 52/100
# 52/52 [==============================] - 0s 1ms/step - loss: -876.9286 - accuracy: 0.6210
# Epoch 53/100
# 52/52 [==============================] - 0s 1ms/step - loss: -909.9658 - accuracy: 0.6167
# Epoch 54/100
# 52/52 [==============================] - 0s 1ms/step - loss: -943.4577 - accuracy: 0.6173
# Epoch 55/100
# 52/52 [==============================] - 0s 1ms/step - loss: -976.9974 - accuracy: 0.6155
# Epoch 56/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1011.6871 - accuracy: 0.6167
# Epoch 57/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1046.3965 - accuracy: 0.6149
# Epoch 58/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1081.3378 - accuracy: 0.6186
# Epoch 59/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1116.7053 - accuracy: 0.6198
# Epoch 60/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1152.5641 - accuracy: 0.6216
# Epoch 61/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1189.2937 - accuracy: 0.6216
# Epoch 62/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1225.9032 - accuracy: 0.6210
# Epoch 63/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1263.6646 - accuracy: 0.6228
# Epoch 64/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1300.9275 - accuracy: 0.6228
# Epoch 65/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1339.0750 - accuracy: 0.6210
# Epoch 66/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1377.7527 - accuracy: 0.6216
# Epoch 67/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1416.9899 - accuracy: 0.6216
# Epoch 68/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1456.7015 - accuracy: 0.6210
# Epoch 69/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1495.9968 - accuracy: 0.6216
# Epoch 70/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1536.6519 - accuracy: 0.6210
# Epoch 71/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1576.8981 - accuracy: 0.6204
# Epoch 72/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1618.2657 - accuracy: 0.6210
# Epoch 73/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1659.9529 - accuracy: 0.6204
# Epoch 74/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1701.3503 - accuracy: 0.6198
# Epoch 75/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1744.0483 - accuracy: 0.6198
# Epoch 76/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1786.1747 - accuracy: 0.6186
# Epoch 77/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1829.5487 - accuracy: 0.6186
# Epoch 78/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1872.6562 - accuracy: 0.6204
# Epoch 79/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1916.8490 - accuracy: 0.6222
# Epoch 80/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1961.4048 - accuracy: 0.6204
# Epoch 81/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2006.2961 - accuracy: 0.6204
# Epoch 82/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2051.2610 - accuracy: 0.6210
# Epoch 83/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2097.2581 - accuracy: 0.6198
# Epoch 84/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2144.0510 - accuracy: 0.6204
# Epoch 85/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2191.3542 - accuracy: 0.6210
# Epoch 86/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2238.7051 - accuracy: 0.6222
# Epoch 87/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2286.4565 - accuracy: 0.6210
# Epoch 88/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2334.5029 - accuracy: 0.6210
# Epoch 89/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2382.3486 - accuracy: 0.6204
# Epoch 90/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2430.2214 - accuracy: 0.6222
# Epoch 91/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2479.9458 - accuracy: 0.6216
# Epoch 92/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2529.5991 - accuracy: 0.6216
# Epoch 93/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2580.0664 - accuracy: 0.6216
# Epoch 94/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2630.1562 - accuracy: 0.6228
# Epoch 95/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2681.2483 - accuracy: 0.6222
# Epoch 96/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2732.2627 - accuracy: 0.6228
# Epoch 97/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2784.1875 - accuracy: 0.6222
# Epoch 98/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2835.9827 - accuracy: 0.6222
# Epoch 99/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2888.7722 - accuracy: 0.6228
# Epoch 100/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2940.0247 - accuracy: 0.6222
# 18/18 - 0s - loss: -2.8167e+03 - accuracy: 0.6345 - 113ms/epoch - 6ms/step
# Loss: -2816.740234375, Accuracy: 0.6345454454421997
