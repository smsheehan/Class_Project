# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
import numpy as np

# Import our input dataset
df = pd.read_excel('Percent_Total_Homeless_DroppedColumns_AllCoC.xlsx')
df.head()
# Out:
#    Year  TotalHomeless  Population  Unemployment  Unsheltered_perc_tot  \
# 0  2019           1111      288000           4.4              8.730873
# 1  2018           1094      290521           5.0              8.592322
# 2  2017           1128      294338           5.4             13.741135
# 3  2016           1105      297249           5.3             21.719457
# 4  2015           1208      297547           4.9             14.817881
#
#    TotalBeds_perc_tot  Emergency_perc_tot  Transitional_perc_tot  \
# 0           92.979298           71.917192              21.062106
# 1           93.967093           68.464351              25.502742
# 2           90.691489           52.925532              37.765957
# 3           91.131222           50.045249              41.085973
# 4           84.354305           49.917219              34.437086
#
#    SafeHaven_perc_tot  PermanentSupportive_perc_tot  PermanentOther_perc_tot  \
# 0                 0.0                     54.095410                 6.390639
# 1                 0.0                     55.210238                 6.489945
# 2                 0.0                     50.620567                 6.294326
# 3                 0.0                     39.276018                 8.778281
# 4                 0.0                     40.728477                 5.877483
#
#    RapidRehousing_perc_tot
# 0                15.391539
# 1                11.425960
# 2                 3.812057
# 3                 4.977376
# 4                 2.317881

# %%
# df2 = df.drop(['Year', 'TotalBeds', 'TotalHomeless'], axis=1)
# df2.head()
# Out:
#    Population  Unemployment  Unsheltered_perc_tot  TotalBeds_perc_tot  \
# 0     1047279           4.5             26.311953           89.650146
# 1     1036554           4.4             26.304348           86.666667
# 2     1026391           4.6             24.459975           82.528590
# 3     1016707           5.0             21.586402          103.626062
# 4     1009103           5.5             19.484702          104.616210
#
#    Emergency_perc_tot  Transitional_perc_tot  SafeHaven_perc_tot  \
# 0           55.903790              32.653061            1.093294
# 1           55.072464              30.507246            1.086957
# 2           48.792884              32.782719            0.952986
# 3           44.305949              58.470255            0.849858
# 4           36.285561              67.525497            0.805153
#
#    PermanentSupportive_perc_tot  PermanentOther_perc_tot  \
# 0                    125.728863                      0.0
# 1                    134.275362                      0.0
# 2                    128.589581                      0.0
# 3                    101.869688                      0.0
# 4                     94.095545                      0.0
#
#    RapidRehousing_perc_tot
# 0                39.868805
# 1                50.217391
# 2                19.123253
# 3                29.745042
# 4                15.619968

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          2199 non-null   int64
#  1   TotalHomeless                 2199 non-null   int64
#  2   Population                    2199 non-null   int64
#  3   Unemployment                  2199 non-null   float64
#  4   Unsheltered_perc_tot          2199 non-null   float64
#  5   TotalBeds_perc_tot            2199 non-null   float64
#  6   Emergency_perc_tot            2199 non-null   float64
#  7   Transitional_perc_tot         2199 non-null   float64
#  8   SafeHaven_perc_tot            2199 non-null   float64
#  9   PermanentSupportive_perc_tot  2199 non-null   float64
#  10  PermanentOther_perc_tot       2199 non-null   float64
#  11  RapidRehousing_perc_tot       2199 non-null   float64
# dtypes: float64(9), int64(3)
# memory usage: 206.3 KB

# %%
q = df['Unsheltered_perc_tot'].quantile(np.arange(10) / 10)

# %%
df['UnshelteredPercentQuantile'] = df['Unsheltered_perc_tot'].apply(lambda x : q.index[np.searchsorted(q, x, side='right')-1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          2199 non-null   int64
#  1   TotalHomeless                 2199 non-null   int64
#  2   Population                    2199 non-null   int64
#  3   Unemployment                  2199 non-null   float64
#  4   Unsheltered_perc_tot          2199 non-null   float64
#  5   TotalBeds_perc_tot            2199 non-null   float64
#  6   Emergency_perc_tot            2199 non-null   float64
#  7   Transitional_perc_tot         2199 non-null   float64
#  8   SafeHaven_perc_tot            2199 non-null   float64
#  9   PermanentSupportive_perc_tot  2199 non-null   float64
#  10  PermanentOther_perc_tot       2199 non-null   float64
#  11  RapidRehousing_perc_tot       2199 non-null   float64
#  12  UnshelteredPercentQuantile    2199 non-null   float64
# dtypes: float64(10), int64(3)
# memory usage: 223.5 KB

# %%
df=df.drop('Unsheltered_perc_tot', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          2199 non-null   int64
#  1   TotalHomeless                 2199 non-null   int64
#  2   Population                    2199 non-null   int64
#  3   Unemployment                  2199 non-null   float64
#  4   TotalBeds_perc_tot            2199 non-null   float64
#  5   Emergency_perc_tot            2199 non-null   float64
#  6   Transitional_perc_tot         2199 non-null   float64
#  7   SafeHaven_perc_tot            2199 non-null   float64
#  8   PermanentSupportive_perc_tot  2199 non-null   float64
#  9   PermanentOther_perc_tot       2199 non-null   float64
#  10  RapidRehousing_perc_tot       2199 non-null   float64
#  11  UnshelteredPercentQuantile    2199 non-null   float64
# dtypes: float64(9), int64(3)
# memory usage: 206.3 KB

# %%
# Remove outcome target from features data
y = df.UnshelteredPercentQuantile.values
X = df.drop(columns="UnshelteredPercentQuantile").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=64, activation="sigmoid", input_dim=11))
nn_model.add(tf.keras.layers.Dense(units=64, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6430 - accuracy: 0.0910
# Epoch 2/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6097 - accuracy: 0.0831
# Epoch 3/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6068 - accuracy: 0.0819
# Epoch 4/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6086 - accuracy: 0.0831
# Epoch 5/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6073 - accuracy: 0.0807
# Epoch 6/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6065 - accuracy: 0.0807
# Epoch 7/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6070 - accuracy: 0.0819
# Epoch 8/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6039 - accuracy: 0.0819
# Epoch 9/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6036 - accuracy: 0.0825
# Epoch 10/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6043 - accuracy: 0.0813
# Epoch 11/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6045 - accuracy: 0.0825
# Epoch 12/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6060 - accuracy: 0.0807
# Epoch 13/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6038 - accuracy: 0.0819
# Epoch 14/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6024 - accuracy: 0.0819
# Epoch 15/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6014 - accuracy: 0.0813
# Epoch 16/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6043 - accuracy: 0.0819
# Epoch 17/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6017 - accuracy: 0.0831
# Epoch 18/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6013 - accuracy: 0.0813
# Epoch 19/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6008 - accuracy: 0.0807
# Epoch 20/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6005 - accuracy: 0.0831
# Epoch 21/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5991 - accuracy: 0.0825
# Epoch 22/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5983 - accuracy: 0.0819
# Epoch 23/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5974 - accuracy: 0.0819
# Epoch 24/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5970 - accuracy: 0.0819
# Epoch 25/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5966 - accuracy: 0.0825
# Epoch 26/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5966 - accuracy: 0.0837
# Epoch 27/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5969 - accuracy: 0.0837
# Epoch 28/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5962 - accuracy: 0.0831
# Epoch 29/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5973 - accuracy: 0.0831
# Epoch 30/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5948 - accuracy: 0.0843
# Epoch 31/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5939 - accuracy: 0.0849
# Epoch 32/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5935 - accuracy: 0.0855
# Epoch 33/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5929 - accuracy: 0.0867
# Epoch 34/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5946 - accuracy: 0.0879
# Epoch 35/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5925 - accuracy: 0.0861
# Epoch 36/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5930 - accuracy: 0.0867
# Epoch 37/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5925 - accuracy: 0.0861
# Epoch 38/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5918 - accuracy: 0.0849
# Epoch 39/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5911 - accuracy: 0.0873
# Epoch 40/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5909 - accuracy: 0.0861
# Epoch 41/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5902 - accuracy: 0.0867
# Epoch 42/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5899 - accuracy: 0.0873
# Epoch 43/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5907 - accuracy: 0.0861
# Epoch 44/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5892 - accuracy: 0.0861
# Epoch 45/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5889 - accuracy: 0.0867
# Epoch 46/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5915 - accuracy: 0.0873
# Epoch 47/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5912 - accuracy: 0.0873
# Epoch 48/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5892 - accuracy: 0.0861
# Epoch 49/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5882 - accuracy: 0.0873
# Epoch 50/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5881 - accuracy: 0.0898
# Epoch 51/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5866 - accuracy: 0.0891
# Epoch 52/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5873 - accuracy: 0.0879
# Epoch 53/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5863 - accuracy: 0.0885
# Epoch 54/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5869 - accuracy: 0.0891
# Epoch 55/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5864 - accuracy: 0.0885
# Epoch 56/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5856 - accuracy: 0.0891
# Epoch 57/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5850 - accuracy: 0.0891
# Epoch 58/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5856 - accuracy: 0.0885
# Epoch 59/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5852 - accuracy: 0.0891
# Epoch 60/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5850 - accuracy: 0.0885
# Epoch 61/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5849 - accuracy: 0.0898
# Epoch 62/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5843 - accuracy: 0.0885
# Epoch 63/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5837 - accuracy: 0.0891
# Epoch 64/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5840 - accuracy: 0.0891
# Epoch 65/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5836 - accuracy: 0.0898
# Epoch 66/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5840 - accuracy: 0.0891
# Epoch 67/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5840 - accuracy: 0.0873
# Epoch 68/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5838 - accuracy: 0.0898
# Epoch 69/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5834 - accuracy: 0.0885
# Epoch 70/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5826 - accuracy: 0.0885
# Epoch 71/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5816 - accuracy: 0.0891
# Epoch 72/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5841 - accuracy: 0.0879
# Epoch 73/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5821 - accuracy: 0.0910
# Epoch 74/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5825 - accuracy: 0.0885
# Epoch 75/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5818 - accuracy: 0.0879
# Epoch 76/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5818 - accuracy: 0.0904
# Epoch 77/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5819 - accuracy: 0.0885
# Epoch 78/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5830 - accuracy: 0.0879
# Epoch 79/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5810 - accuracy: 0.0891
# Epoch 80/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5846 - accuracy: 0.0891
# Epoch 81/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5818 - accuracy: 0.0885
# Epoch 82/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5812 - accuracy: 0.0904
# Epoch 83/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5798 - accuracy: 0.0904
# Epoch 84/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5817 - accuracy: 0.0891
# Epoch 85/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5807 - accuracy: 0.0904
# Epoch 86/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5800 - accuracy: 0.0891
# Epoch 87/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5800 - accuracy: 0.0885
# Epoch 88/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5796 - accuracy: 0.0898
# Epoch 89/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5794 - accuracy: 0.0898
# Epoch 90/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5791 - accuracy: 0.0891
# Epoch 91/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5792 - accuracy: 0.0891
# Epoch 92/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5789 - accuracy: 0.0904
# Epoch 93/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5799 - accuracy: 0.0885
# Epoch 94/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5789 - accuracy: 0.0904
# Epoch 95/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5788 - accuracy: 0.0891
# Epoch 96/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5798 - accuracy: 0.0916
# Epoch 97/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5779 - accuracy: 0.0898
# Epoch 98/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5780 - accuracy: 0.0891
# Epoch 99/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5786 - accuracy: 0.0898
# Epoch 100/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5787 - accuracy: 0.0891
# 18/18 - 0s - loss: 0.5815 - accuracy: 0.0945 - 108ms/epoch - 6ms/step
# Loss: 0.5814591646194458, Accuracy: 0.09454545378684998
