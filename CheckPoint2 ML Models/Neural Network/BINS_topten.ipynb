# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
import numpy as np

# Import our input dataset
df = pd.read_excel('Percent_Total_Homeless_DroppedColumns_AllCoC.xlsx')
df.head()
# Out:
#    Year  TotalHomeless  Population  Unemployment  Unsheltered_perc_tot  \
# 0  2019           1111      288000           4.4              8.730873
# 1  2018           1094      290521           5.0              8.592322
# 2  2017           1128      294338           5.4             13.741135
# 3  2016           1105      297249           5.3             21.719457
# 4  2015           1208      297547           4.9             14.817881
#
#    TotalBeds_perc_tot  Emergency_perc_tot  Transitional_perc_tot  \
# 0           92.979298           71.917192              21.062106
# 1           93.967093           68.464351              25.502742
# 2           90.691489           52.925532              37.765957
# 3           91.131222           50.045249              41.085973
# 4           84.354305           49.917219              34.437086
#
#    SafeHaven_perc_tot  PermanentSupportive_perc_tot  PermanentOther_perc_tot  \
# 0                 0.0                     54.095410                 6.390639
# 1                 0.0                     55.210238                 6.489945
# 2                 0.0                     50.620567                 6.294326
# 3                 0.0                     39.276018                 8.778281
# 4                 0.0                     40.728477                 5.877483
#
#    RapidRehousing_perc_tot
# 0                15.391539
# 1                11.425960
# 2                 3.812057
# 3                 4.977376
# 4                 2.317881

# %%
#df["SafeHaven_perc_tot"] = df["SafeHaven_perc_tot"].astype(bool).astype(int)

# %%
df = df.drop(['TotalHomeless', 'Population', 'Year' ], axis=1)
df.head()
# Out:
#    Unemployment  Unsheltered_perc_tot  TotalBeds_perc_tot  Emergency_perc_tot  \
# 0           4.4              8.730873           92.979298           71.917192
# 1           5.0              8.592322           93.967093           68.464351
# 2           5.4             13.741135           90.691489           52.925532
# 3           5.3             21.719457           91.131222           50.045249
# 4           4.9             14.817881           84.354305           49.917219
#
#    Transitional_perc_tot  SafeHaven_perc_tot  PermanentSupportive_perc_tot  \
# 0              21.062106                 0.0                     54.095410
# 1              25.502742                 0.0                     55.210238
# 2              37.765957                 0.0                     50.620567
# 3              41.085973                 0.0                     39.276018
# 4              34.437086                 0.0                     40.728477
#
#    PermanentOther_perc_tot  RapidRehousing_perc_tot
# 0                 6.390639                15.391539
# 1                 6.489945                11.425960
# 2                 6.294326                 3.812057
# 3                 8.778281                 4.977376
# 4                 5.877483                 2.317881

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unemployment                  2199 non-null   float64
#  1   Unsheltered_perc_tot          2199 non-null   float64
#  2   TotalBeds_perc_tot            2199 non-null   float64
#  3   Emergency_perc_tot            2199 non-null   float64
#  4   Transitional_perc_tot         2199 non-null   float64
#  5   SafeHaven_perc_tot            2199 non-null   float64
#  6   PermanentSupportive_perc_tot  2199 non-null   float64
#  7   PermanentOther_perc_tot       2199 non-null   float64
#  8   RapidRehousing_perc_tot       2199 non-null   float64
# dtypes: float64(9)
# memory usage: 154.7 KB

# %%
df.head()
# Out:
#    Unemployment  Unsheltered_perc_tot  TotalBeds_perc_tot  Emergency_perc_tot  \
# 0           4.4              8.730873           92.979298           71.917192
# 1           5.0              8.592322           93.967093           68.464351
# 2           5.4             13.741135           90.691489           52.925532
# 3           5.3             21.719457           91.131222           50.045249
# 4           4.9             14.817881           84.354305           49.917219
#
#    Transitional_perc_tot  SafeHaven_perc_tot  PermanentSupportive_perc_tot  \
# 0              21.062106                 0.0                     54.095410
# 1              25.502742                 0.0                     55.210238
# 2              37.765957                 0.0                     50.620567
# 3              41.085973                 0.0                     39.276018
# 4              34.437086                 0.0                     40.728477
#
#    PermanentOther_perc_tot  RapidRehousing_perc_tot
# 0                 6.390639                15.391539
# 1                 6.489945                11.425960
# 2                 6.294326                 3.812057
# 3                 8.778281                 4.977376
# 4                 5.877483                 2.317881

# %%
#q = df['Unsheltered_perc_tot'].quantile(np.arange(10) / 10)

# %%
#df['UnshelteredPercentQuantile'] = df['Unsheltered_perc_tot'].apply(lambda x : q.index[np.searchsorted(q, x, side='right')-1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unemployment                  2199 non-null   float64
#  1   Unsheltered_perc_tot          2199 non-null   float64
#  2   TotalBeds_perc_tot            2199 non-null   float64
#  3   Emergency_perc_tot            2199 non-null   float64
#  4   Transitional_perc_tot         2199 non-null   float64
#  5   SafeHaven_perc_tot            2199 non-null   float64
#  6   PermanentSupportive_perc_tot  2199 non-null   float64
#  7   PermanentOther_perc_tot       2199 non-null   float64
#  8   RapidRehousing_perc_tot       2199 non-null   float64
# dtypes: float64(9)
# memory usage: 154.7 KB

# %%
#pd.cut(df['Unsheltered_perc_tot'], bins=3).value_counts()

# %%
size_bins=[-1, 10, 100]
group_names = ["0", "1"]

# %%
df['Unshelteredtenthreshold'] = pd.cut(df['Unsheltered_perc_tot'], size_bins, labels=group_names)

# %%
df['Unshelteredtenthreshold'] = df['Unshelteredtenthreshold'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unemployment                  2199 non-null   float64
#  1   Unsheltered_perc_tot          2199 non-null   float64
#  2   TotalBeds_perc_tot            2199 non-null   float64
#  3   Emergency_perc_tot            2199 non-null   float64
#  4   Transitional_perc_tot         2199 non-null   float64
#  5   SafeHaven_perc_tot            2199 non-null   float64
#  6   PermanentSupportive_perc_tot  2199 non-null   float64
#  7   PermanentOther_perc_tot       2199 non-null   float64
#  8   RapidRehousing_perc_tot       2199 non-null   float64
#  9   Unshelteredtenthreshold       2199 non-null   int32
# dtypes: float64(9), int32(1)
# memory usage: 163.3 KB

# %%
# Remove outcome target from features data
y = df.Unshelteredtenthreshold.values
X = df.drop(columns="Unshelteredtenthreshold").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

# %%
# # Preprocess numerical data for neural network

# # Create a StandardScaler instances
# scaler = StandardScaler()

# # Fit the StandardScaler
# X_scaler = scaler.fit(X_train)

# # Scale the data
# X_train_scaled = X_scaler.transform(X_train)
# X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=64, activation="sigmoid", input_dim=9))
nn_model.add(tf.keras.layers.Dense(units=32, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5109 - accuracy: 0.7168
# Epoch 2/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.3536 - accuracy: 0.8654
# Epoch 3/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.2514 - accuracy: 0.9333
# Epoch 4/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.1891 - accuracy: 0.9381
# Epoch 5/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.1561 - accuracy: 0.9454
# Epoch 6/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.1278 - accuracy: 0.9515
# Epoch 7/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.1138 - accuracy: 0.9539
# Epoch 8/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0993 - accuracy: 0.9630
# Epoch 9/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0957 - accuracy: 0.9691
# Epoch 10/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0957 - accuracy: 0.9642
# Epoch 11/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0895 - accuracy: 0.9648
# Epoch 12/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0822 - accuracy: 0.9733
# Epoch 13/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0804 - accuracy: 0.9727
# Epoch 14/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0799 - accuracy: 0.9685
# Epoch 15/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0795 - accuracy: 0.9654
# Epoch 16/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0751 - accuracy: 0.9770
# Epoch 17/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0825 - accuracy: 0.9691
# Epoch 18/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0689 - accuracy: 0.9770
# Epoch 19/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0643 - accuracy: 0.9800
# Epoch 20/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0702 - accuracy: 0.9745
# Epoch 21/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0678 - accuracy: 0.9763
# Epoch 22/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0699 - accuracy: 0.9685
# Epoch 23/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0631 - accuracy: 0.9763
# Epoch 24/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0854 - accuracy: 0.9630
# Epoch 25/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0740 - accuracy: 0.9685
# Epoch 26/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0594 - accuracy: 0.9818
# Epoch 27/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0611 - accuracy: 0.9782
# Epoch 28/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0728 - accuracy: 0.9691
# Epoch 29/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0615 - accuracy: 0.9745
# Epoch 30/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0700 - accuracy: 0.9733
# Epoch 31/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0608 - accuracy: 0.9739
# Epoch 32/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0523 - accuracy: 0.9806
# Epoch 33/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0535 - accuracy: 0.9806
# Epoch 34/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0507 - accuracy: 0.9836
# Epoch 35/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0579 - accuracy: 0.9800
# Epoch 36/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0478 - accuracy: 0.9824
# Epoch 37/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0487 - accuracy: 0.9836
# Epoch 38/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0521 - accuracy: 0.9788
# Epoch 39/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0484 - accuracy: 0.9824
# Epoch 40/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0450 - accuracy: 0.9854
# Epoch 41/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0471 - accuracy: 0.9836
# Epoch 42/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0447 - accuracy: 0.9824
# Epoch 43/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0413 - accuracy: 0.9861
# Epoch 44/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0451 - accuracy: 0.9824
# Epoch 45/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0421 - accuracy: 0.9873
# Epoch 46/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0405 - accuracy: 0.9861
# Epoch 47/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0545 - accuracy: 0.9782
# Epoch 48/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0435 - accuracy: 0.9836
# Epoch 49/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0398 - accuracy: 0.9842
# Epoch 50/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0414 - accuracy: 0.9824
# Epoch 51/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0387 - accuracy: 0.9861
# Epoch 52/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0378 - accuracy: 0.9830
# Epoch 53/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0422 - accuracy: 0.9842
# Epoch 54/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0361 - accuracy: 0.9891
# Epoch 55/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0357 - accuracy: 0.9861
# Epoch 56/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0406 - accuracy: 0.9830
# Epoch 57/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0607 - accuracy: 0.9721
# Epoch 58/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0793 - accuracy: 0.9715
# Epoch 59/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0460 - accuracy: 0.9842
# Epoch 60/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0385 - accuracy: 0.9861
# Epoch 61/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0371 - accuracy: 0.9897
# Epoch 62/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0338 - accuracy: 0.9903
# Epoch 63/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0411 - accuracy: 0.9824
# Epoch 64/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0392 - accuracy: 0.9800
# Epoch 65/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0281 - accuracy: 0.9933
# Epoch 66/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0296 - accuracy: 0.9903
# Epoch 67/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0407 - accuracy: 0.9842
# Epoch 68/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0338 - accuracy: 0.9885
# Epoch 69/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0285 - accuracy: 0.9921
# Epoch 70/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0352 - accuracy: 0.9879
# Epoch 71/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0300 - accuracy: 0.9915
# Epoch 72/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0279 - accuracy: 0.9921
# Epoch 73/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0436 - accuracy: 0.9830
# Epoch 74/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0378 - accuracy: 0.9885
# Epoch 75/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0325 - accuracy: 0.9854
# Epoch 76/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0264 - accuracy: 0.9927
# Epoch 77/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0256 - accuracy: 0.9909
# Epoch 78/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0260 - accuracy: 0.9903
# Epoch 79/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0349 - accuracy: 0.9873
# Epoch 80/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 0.9933
# Epoch 81/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0264 - accuracy: 0.9915
# Epoch 82/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0263 - accuracy: 0.9909
# Epoch 83/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0310 - accuracy: 0.9879
# Epoch 84/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0277 - accuracy: 0.9903
# Epoch 85/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0229 - accuracy: 0.9921
# Epoch 86/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0243 - accuracy: 0.9909
# Epoch 87/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0233 - accuracy: 0.9927
# Epoch 88/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0313 - accuracy: 0.9854
# Epoch 89/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0255 - accuracy: 0.9885
# Epoch 90/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0212 - accuracy: 0.9933
# Epoch 91/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0276 - accuracy: 0.9885
# Epoch 92/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0283 - accuracy: 0.9891
# Epoch 93/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0345 - accuracy: 0.9854
# Epoch 94/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 0.9909
# Epoch 95/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0222 - accuracy: 0.9921
# Epoch 96/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0266 - accuracy: 0.9903
# Epoch 97/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0231 - accuracy: 0.9933
# Epoch 98/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0209 - accuracy: 0.9927
# Epoch 99/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0165 - accuracy: 0.9964
# Epoch 100/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0216 - accuracy: 0.9903
# 18/18 - 0s - loss: 0.0669 - accuracy: 0.9727 - 123ms/epoch - 7ms/step
# Loss: 0.06694722920656204, Accuracy: 0.9727272987365723
