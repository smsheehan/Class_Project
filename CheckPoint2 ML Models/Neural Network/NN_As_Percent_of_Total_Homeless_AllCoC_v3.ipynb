# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
import numpy as np

# Import our input dataset
df = pd.read_excel('Percent_Total_Homeless_DroppedColumns_AllCoC.xlsx')
df.head()
# Out:
#    Year  TotalHomeless  Population  Unemployment  Unsheltered_perc_tot  \
# 0  2019           1111      288000           4.4              8.730873
# 1  2018           1094      290521           5.0              8.592322
# 2  2017           1128      294338           5.4             13.741135
# 3  2016           1105      297249           5.3             21.719457
# 4  2015           1208      297547           4.9             14.817881
#
#    TotalBeds_perc_tot  Emergency_perc_tot  Transitional_perc_tot  \
# 0           92.979298           71.917192              21.062106
# 1           93.967093           68.464351              25.502742
# 2           90.691489           52.925532              37.765957
# 3           91.131222           50.045249              41.085973
# 4           84.354305           49.917219              34.437086
#
#    SafeHaven_perc_tot  PermanentSupportive_perc_tot  PermanentOther_perc_tot  \
# 0                 0.0                     54.095410                 6.390639
# 1                 0.0                     55.210238                 6.489945
# 2                 0.0                     50.620567                 6.294326
# 3                 0.0                     39.276018                 8.778281
# 4                 0.0                     40.728477                 5.877483
#
#    RapidRehousing_perc_tot
# 0                15.391539
# 1                11.425960
# 2                 3.812057
# 3                 4.977376
# 4                 2.317881

# %%
# df2 = df.drop(['Year', 'TotalBeds', 'TotalHomeless'], axis=1)
# df2.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          2199 non-null   int64
#  1   TotalHomeless                 2199 non-null   int64
#  2   Population                    2199 non-null   int64
#  3   Unemployment                  2199 non-null   float64
#  4   Unsheltered_perc_tot          2199 non-null   float64
#  5   TotalBeds_perc_tot            2199 non-null   float64
#  6   Emergency_perc_tot            2199 non-null   float64
#  7   Transitional_perc_tot         2199 non-null   float64
#  8   SafeHaven_perc_tot            2199 non-null   float64
#  9   PermanentSupportive_perc_tot  2199 non-null   float64
#  10  PermanentOther_perc_tot       2199 non-null   float64
#  11  RapidRehousing_perc_tot       2199 non-null   float64
# dtypes: float64(9), int64(3)
# memory usage: 206.3 KB

# %%
# q = df['Unsheltered_perc_tot'].quantile(np.arange(10) / 10)

# %%
# df['UnshelteredPercentQuantile'] = df['Unsheltered_perc_tot'].apply(lambda x : q.index[np.searchsorted(q, x, side='right')-1])

# %%
pd.cut(df['Unsheltered_perc_tot'], bins=3).value_counts()
# Out:
# (-0.0961, 32.033]    1500
# (32.033, 64.065]      484
# (64.065, 96.098]      215
# Name: Unsheltered_perc_tot, dtype: int64

# %%
size_bins=[-1, 33, 66, 100]
group_names = ["0", "1", "2"]

# %%
df['Unsheltered_thirds'] = pd.cut(df['Unsheltered_perc_tot'], size_bins, labels=group_names)

# %%
df['Unsheltered_thirds'] = df['Unsheltered_thirds'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          2199 non-null   int64
#  1   TotalHomeless                 2199 non-null   int64
#  2   Population                    2199 non-null   int64
#  3   Unemployment                  2199 non-null   float64
#  4   Unsheltered_perc_tot          2199 non-null   float64
#  5   TotalBeds_perc_tot            2199 non-null   float64
#  6   Emergency_perc_tot            2199 non-null   float64
#  7   Transitional_perc_tot         2199 non-null   float64
#  8   SafeHaven_perc_tot            2199 non-null   float64
#  9   PermanentSupportive_perc_tot  2199 non-null   float64
#  10  PermanentOther_perc_tot       2199 non-null   float64
#  11  RapidRehousing_perc_tot       2199 non-null   float64
#  12  Unsheltered_thirds            2199 non-null   int32
# dtypes: float64(9), int32(1), int64(3)
# memory usage: 214.9 KB

# %%
df=df.drop(['Unsheltered_perc_tot', 'Year'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   TotalHomeless                 2199 non-null   int64
#  1   Population                    2199 non-null   int64
#  2   Unemployment                  2199 non-null   float64
#  3   TotalBeds_perc_tot            2199 non-null   float64
#  4   Emergency_perc_tot            2199 non-null   float64
#  5   Transitional_perc_tot         2199 non-null   float64
#  6   SafeHaven_perc_tot            2199 non-null   float64
#  7   PermanentSupportive_perc_tot  2199 non-null   float64
#  8   PermanentOther_perc_tot       2199 non-null   float64
#  9   RapidRehousing_perc_tot       2199 non-null   float64
#  10  Unsheltered_thirds            2199 non-null   int32
# dtypes: float64(8), int32(1), int64(2)
# memory usage: 180.5 KB

# %%
# Remove outcome target from features data
y = df.Unsheltered_thirds.values
X = df.drop(columns="Unsheltered_thirds").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=64, activation="sigmoid", input_dim=10))
nn_model.add(tf.keras.layers.Dense(units=32, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 52/52 [==============================] - 0s 896us/step - loss: 0.5784 - accuracy: 0.7083
# Epoch 2/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.3692 - accuracy: 0.7592
# Epoch 3/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.1923 - accuracy: 0.7629
# Epoch 4/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0649 - accuracy: 0.7592
# Epoch 5/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.0323 - accuracy: 0.7526
# Epoch 6/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.1072 - accuracy: 0.7489
# Epoch 7/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.1749 - accuracy: 0.7477
# Epoch 8/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.2423 - accuracy: 0.7453
# Epoch 9/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.3247 - accuracy: 0.7471
# Epoch 10/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.3912 - accuracy: 0.7423
# Epoch 11/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.4898 - accuracy: 0.7502
# Epoch 12/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.5694 - accuracy: 0.7453
# Epoch 13/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.6772 - accuracy: 0.7471
# Epoch 14/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.7732 - accuracy: 0.7483
# Epoch 15/100
# 52/52 [==============================] - 0s 1000us/step - loss: -0.8805 - accuracy: 0.7483
# Epoch 16/100
# 52/52 [==============================] - 0s 961us/step - loss: -1.0110 - accuracy: 0.7477
# Epoch 17/100
# 52/52 [==============================] - 0s 942us/step - loss: -1.1457 - accuracy: 0.7453
# Epoch 18/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1.2999 - accuracy: 0.7453
# Epoch 19/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1.4298 - accuracy: 0.7538
# Epoch 20/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1.6299 - accuracy: 0.7514
# Epoch 21/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1.8279 - accuracy: 0.7483
# Epoch 22/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2.0379 - accuracy: 0.7465
# Epoch 23/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2.2789 - accuracy: 0.7495
# Epoch 24/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2.5362 - accuracy: 0.7514
# Epoch 25/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2.8054 - accuracy: 0.7489
# Epoch 26/100
# 52/52 [==============================] - 0s 1ms/step - loss: -3.1203 - accuracy: 0.7471
# Epoch 27/100
# 52/52 [==============================] - 0s 1ms/step - loss: -3.4994 - accuracy: 0.7508
# Epoch 28/100
# 52/52 [==============================] - 0s 1ms/step - loss: -3.9031 - accuracy: 0.7508
# Epoch 29/100
# 52/52 [==============================] - 0s 1ms/step - loss: -4.3449 - accuracy: 0.7520
# Epoch 30/100
# 52/52 [==============================] - 0s 1ms/step - loss: -4.8456 - accuracy: 0.7514
# Epoch 31/100
# 52/52 [==============================] - 0s 1ms/step - loss: -5.4058 - accuracy: 0.7526
# Epoch 32/100
# 52/52 [==============================] - 0s 1ms/step - loss: -5.9809 - accuracy: 0.7495
# Epoch 33/100
# 52/52 [==============================] - 0s 2ms/step - loss: -6.6046 - accuracy: 0.7508
# Epoch 34/100
# 52/52 [==============================] - 0s 2ms/step - loss: -7.2535 - accuracy: 0.7477
# Epoch 35/100
# 52/52 [==============================] - 0s 1ms/step - loss: -8.0523 - accuracy: 0.7514
# Epoch 36/100
# 52/52 [==============================] - 0s 1ms/step - loss: -8.8462 - accuracy: 0.7477
# Epoch 37/100
# 52/52 [==============================] - 0s 2ms/step - loss: -9.7233 - accuracy: 0.7550
# Epoch 38/100
# 52/52 [==============================] - 0s 1ms/step - loss: -10.7628 - accuracy: 0.7514
# Epoch 39/100
# 52/52 [==============================] - 0s 1ms/step - loss: -11.8092 - accuracy: 0.7520
# Epoch 40/100
# 52/52 [==============================] - 0s 1ms/step - loss: -12.9207 - accuracy: 0.7489
# Epoch 41/100
# 52/52 [==============================] - 0s 1ms/step - loss: -14.1611 - accuracy: 0.7508
# Epoch 42/100
# 52/52 [==============================] - 0s 1ms/step - loss: -15.4759 - accuracy: 0.7508
# Epoch 43/100
# 52/52 [==============================] - 0s 1ms/step - loss: -16.9217 - accuracy: 0.7550
# Epoch 44/100
# 52/52 [==============================] - 0s 1ms/step - loss: -18.4570 - accuracy: 0.7495
# Epoch 45/100
# 52/52 [==============================] - 0s 1ms/step - loss: -19.9841 - accuracy: 0.7550
# Epoch 46/100
# 52/52 [==============================] - 0s 1ms/step - loss: -21.6382 - accuracy: 0.7520
# Epoch 47/100
# 52/52 [==============================] - 0s 1ms/step - loss: -23.3214 - accuracy: 0.7514
# Epoch 48/100
# 52/52 [==============================] - 0s 1ms/step - loss: -25.1111 - accuracy: 0.7556
# Epoch 49/100
# 52/52 [==============================] - 0s 1ms/step - loss: -26.9463 - accuracy: 0.7556
# Epoch 50/100
# 52/52 [==============================] - 0s 1ms/step - loss: -28.8625 - accuracy: 0.7538
# Epoch 51/100
# 52/52 [==============================] - 0s 1ms/step - loss: -30.9049 - accuracy: 0.7568
# Epoch 52/100
# 52/52 [==============================] - 0s 1ms/step - loss: -32.8978 - accuracy: 0.7526
# Epoch 53/100
# 52/52 [==============================] - 0s 1ms/step - loss: -35.1703 - accuracy: 0.7544
# Epoch 54/100
# 52/52 [==============================] - 0s 1ms/step - loss: -37.4434 - accuracy: 0.7544
# Epoch 55/100
# 52/52 [==============================] - 0s 1ms/step - loss: -39.5806 - accuracy: 0.7538
# Epoch 56/100
# 52/52 [==============================] - 0s 1ms/step - loss: -42.1411 - accuracy: 0.7550
# Epoch 57/100
# 52/52 [==============================] - 0s 1ms/step - loss: -44.6353 - accuracy: 0.7544
# Epoch 58/100
# 52/52 [==============================] - 0s 1ms/step - loss: -47.2216 - accuracy: 0.7520
# Epoch 59/100
# 52/52 [==============================] - 0s 1ms/step - loss: -49.9011 - accuracy: 0.7550
# Epoch 60/100
# 52/52 [==============================] - 0s 1ms/step - loss: -52.5995 - accuracy: 0.7526
# Epoch 61/100
# 52/52 [==============================] - 0s 1ms/step - loss: -55.4231 - accuracy: 0.7538
# Epoch 62/100
# 52/52 [==============================] - 0s 1ms/step - loss: -58.2819 - accuracy: 0.7544
# Epoch 63/100
# 52/52 [==============================] - 0s 1ms/step - loss: -61.2531 - accuracy: 0.7544
# Epoch 64/100
# 52/52 [==============================] - 0s 1ms/step - loss: -64.4109 - accuracy: 0.7538
# Epoch 65/100
# 52/52 [==============================] - 0s 1ms/step - loss: -67.5695 - accuracy: 0.7550
# Epoch 66/100
# 52/52 [==============================] - 0s 1ms/step - loss: -70.7993 - accuracy: 0.7508
# Epoch 67/100
# 52/52 [==============================] - 0s 1ms/step - loss: -74.1703 - accuracy: 0.7532
# Epoch 68/100
# 52/52 [==============================] - 0s 1ms/step - loss: -77.6027 - accuracy: 0.7556
# Epoch 69/100
# 52/52 [==============================] - 0s 1ms/step - loss: -81.0210 - accuracy: 0.7550
# Epoch 70/100
# 52/52 [==============================] - 0s 1ms/step - loss: -84.5346 - accuracy: 0.7508
# Epoch 71/100
# 52/52 [==============================] - 0s 1ms/step - loss: -88.2121 - accuracy: 0.7562
# Epoch 72/100
# 52/52 [==============================] - 0s 1ms/step - loss: -91.8696 - accuracy: 0.7544
# Epoch 73/100
# 52/52 [==============================] - 0s 1ms/step - loss: -95.5969 - accuracy: 0.7574
# Epoch 74/100
# 52/52 [==============================] - 0s 1ms/step - loss: -99.5155 - accuracy: 0.7550
# Epoch 75/100
# 52/52 [==============================] - 0s 1ms/step - loss: -103.4905 - accuracy: 0.7586
# Epoch 76/100
# 52/52 [==============================] - 0s 1ms/step - loss: -107.5808 - accuracy: 0.7580
# Epoch 77/100
# 52/52 [==============================] - 0s 1ms/step - loss: -111.7087 - accuracy: 0.7550
# Epoch 78/100
# 52/52 [==============================] - 0s 1ms/step - loss: -115.8167 - accuracy: 0.7568
# Epoch 79/100
# 52/52 [==============================] - 0s 1ms/step - loss: -120.1185 - accuracy: 0.7574
# Epoch 80/100
# 52/52 [==============================] - 0s 1ms/step - loss: -124.4350 - accuracy: 0.7538
# Epoch 81/100
# 52/52 [==============================] - 0s 1ms/step - loss: -128.8280 - accuracy: 0.7520
# Epoch 82/100
# 52/52 [==============================] - 0s 1ms/step - loss: -133.4387 - accuracy: 0.7550
# Epoch 83/100
# 52/52 [==============================] - 0s 1ms/step - loss: -137.9543 - accuracy: 0.7556
# Epoch 84/100
# 52/52 [==============================] - 0s 1ms/step - loss: -142.5983 - accuracy: 0.7586
# Epoch 85/100
# 52/52 [==============================] - 0s 1ms/step - loss: -147.4045 - accuracy: 0.7550
# Epoch 86/100
# 52/52 [==============================] - 0s 1ms/step - loss: -152.1294 - accuracy: 0.7550
# Epoch 87/100
# 52/52 [==============================] - 0s 1ms/step - loss: -156.9283 - accuracy: 0.7544
# Epoch 88/100
# 52/52 [==============================] - 0s 1ms/step - loss: -161.6274 - accuracy: 0.7532
# Epoch 89/100
# 52/52 [==============================] - 0s 1ms/step - loss: -166.5258 - accuracy: 0.7514
# Epoch 90/100
# 52/52 [==============================] - 0s 1ms/step - loss: -171.5127 - accuracy: 0.7550
# Epoch 91/100
# 52/52 [==============================] - 0s 1ms/step - loss: -176.4830 - accuracy: 0.7514
# Epoch 92/100
# 52/52 [==============================] - 0s 1ms/step - loss: -181.5547 - accuracy: 0.7538
# Epoch 93/100
# 52/52 [==============================] - 0s 1ms/step - loss: -186.8881 - accuracy: 0.7532
# Epoch 94/100
# 52/52 [==============================] - 0s 1ms/step - loss: -192.1408 - accuracy: 0.7514
# Epoch 95/100
# 52/52 [==============================] - 0s 1ms/step - loss: -197.3515 - accuracy: 0.7495
# Epoch 96/100
# 52/52 [==============================] - 0s 1ms/step - loss: -202.6924 - accuracy: 0.7489
# Epoch 97/100
# 52/52 [==============================] - 0s 1ms/step - loss: -208.0584 - accuracy: 0.7477
# Epoch 98/100
# 52/52 [==============================] - 0s 1ms/step - loss: -213.5277 - accuracy: 0.7502
# Epoch 99/100
# 52/52 [==============================] - 0s 1ms/step - loss: -219.1789 - accuracy: 0.7441
# Epoch 100/100
# 52/52 [==============================] - 0s 1ms/step - loss: -224.7500 - accuracy: 0.7453
# 18/18 - 0s - loss: -2.5955e+02 - accuracy: 0.7600 - 141ms/epoch - 8ms/step
# Loss: -259.55218505859375, Accuracy: 0.7599999904632568
