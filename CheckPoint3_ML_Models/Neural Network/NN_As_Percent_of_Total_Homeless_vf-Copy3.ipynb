# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
import numpy as np

# Import our input dataset
df = pd.read_excel('Percent_Total_Homeless_DroppedColumns_AllCoC.xlsx')
df.head()
# Out:
#    Year  TotalHomeless  Population  Unemployment  Unsheltered_perc_tot  \
# 0  2019           1111      288000           4.4              8.730873
# 1  2018           1094      290521           5.0              8.592322
# 2  2017           1128      294338           5.4             13.741135
# 3  2016           1105      297249           5.3             21.719457
# 4  2015           1208      297547           4.9             14.817881
#
#    TotalBeds_perc_tot  Emergency_perc_tot  Transitional_perc_tot  \
# 0           92.979298           71.917192              21.062106
# 1           93.967093           68.464351              25.502742
# 2           90.691489           52.925532              37.765957
# 3           91.131222           50.045249              41.085973
# 4           84.354305           49.917219              34.437086
#
#    SafeHaven_perc_tot  PermanentSupportive_perc_tot  PermanentOther_perc_tot  \
# 0                 0.0                     54.095410                 6.390639
# 1                 0.0                     55.210238                 6.489945
# 2                 0.0                     50.620567                 6.294326
# 3                 0.0                     39.276018                 8.778281
# 4                 0.0                     40.728477                 5.877483
#
#    RapidRehousing_perc_tot
# 0                15.391539
# 1                11.425960
# 2                 3.812057
# 3                 4.977376
# 4                 2.317881

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          2199 non-null   int64
#  1   TotalHomeless                 2199 non-null   int64
#  2   Population                    2199 non-null   int64
#  3   Unemployment                  2199 non-null   float64
#  4   Unsheltered_perc_tot          2199 non-null   float64
#  5   TotalBeds_perc_tot            2199 non-null   float64
#  6   Emergency_perc_tot            2199 non-null   float64
#  7   Transitional_perc_tot         2199 non-null   float64
#  8   SafeHaven_perc_tot            2199 non-null   float64
#  9   PermanentSupportive_perc_tot  2199 non-null   float64
#  10  PermanentOther_perc_tot       2199 non-null   float64
#  11  RapidRehousing_perc_tot       2199 non-null   float64
# dtypes: float64(9), int64(3)
# memory usage: 206.3 KB

# %%
pd.cut(df['Unsheltered_perc_tot'], bins=3).value_counts()
# Out:
# (-0.0961, 32.033]    1500
# (32.033, 64.065]      484
# (64.065, 96.098]      215
# Name: Unsheltered_perc_tot, dtype: int64

# %%
size_bins=[-1, 33, 66, 100]
group_names = ["0", "1", "2"]

# %%
df['Unsheltered_thirds'] = pd.cut(df['Unsheltered_perc_tot'], size_bins, labels=group_names)

# %%
df['Unsheltered_thirds'] = df['Unsheltered_thirds'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          2199 non-null   int64
#  1   TotalHomeless                 2199 non-null   int64
#  2   Population                    2199 non-null   int64
#  3   Unemployment                  2199 non-null   float64
#  4   Unsheltered_perc_tot          2199 non-null   float64
#  5   TotalBeds_perc_tot            2199 non-null   float64
#  6   Emergency_perc_tot            2199 non-null   float64
#  7   Transitional_perc_tot         2199 non-null   float64
#  8   SafeHaven_perc_tot            2199 non-null   float64
#  9   PermanentSupportive_perc_tot  2199 non-null   float64
#  10  PermanentOther_perc_tot       2199 non-null   float64
#  11  RapidRehousing_perc_tot       2199 non-null   float64
#  12  Unsheltered_thirds            2199 non-null   int32
# dtypes: float64(9), int32(1), int64(3)
# memory usage: 214.9 KB

# %%
df=df.drop(['Unsheltered_perc_tot', 'RapidRehousing_perc_tot', 'PermanentSupportive_perc_tot', 'PermanentOther_perc_tot', 'Year', 'TotalHomeless', 'Population', 'Unemployment', 'Emergency_perc_tot', 'SafeHaven_perc_tot', 'Transitional_perc_tot'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   TotalBeds_perc_tot  2199 non-null   float64
#  1   Unsheltered_thirds  2199 non-null   int32
# dtypes: float64(1), int32(1)
# memory usage: 25.9 KB

# %%
# Remove outcome target from features data
y = df.Unsheltered_thirds.values
X = df.drop(columns="Unsheltered_thirds").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=64, activation="sigmoid", input_dim=1))
nn_model.add(tf.keras.layers.Dense(units=32, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5816 - accuracy: 0.6962
# Epoch 2/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.4720 - accuracy: 0.7368
# Epoch 3/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.3373 - accuracy: 0.7465
# Epoch 4/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.2156 - accuracy: 0.7514
# Epoch 5/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.1158 - accuracy: 0.7489
# Epoch 6/100
# 52/52 [==============================] - 0s 1ms/step - loss: 0.0419 - accuracy: 0.7417
# Epoch 7/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.0226 - accuracy: 0.7465
# Epoch 8/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.0713 - accuracy: 0.7374
# Epoch 9/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.1191 - accuracy: 0.7362
# Epoch 10/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.1806 - accuracy: 0.7392
# Epoch 11/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.2128 - accuracy: 0.7374
# Epoch 12/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.2602 - accuracy: 0.7326
# Epoch 13/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.3201 - accuracy: 0.7386
# Epoch 14/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.3773 - accuracy: 0.7356
# Epoch 15/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.4274 - accuracy: 0.7362
# Epoch 16/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.4568 - accuracy: 0.7392
# Epoch 17/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.5247 - accuracy: 0.7386
# Epoch 18/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.5795 - accuracy: 0.7301
# Epoch 19/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.6367 - accuracy: 0.7307
# Epoch 20/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.7011 - accuracy: 0.7368
# Epoch 21/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.7417 - accuracy: 0.7332
# Epoch 22/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.8446 - accuracy: 0.7350
# Epoch 23/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.9071 - accuracy: 0.7368
# Epoch 24/100
# 52/52 [==============================] - 0s 1ms/step - loss: -0.9730 - accuracy: 0.7368
# Epoch 25/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1.0738 - accuracy: 0.7362
# Epoch 26/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1.1748 - accuracy: 0.7362
# Epoch 27/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1.2627 - accuracy: 0.7350
# Epoch 28/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1.3714 - accuracy: 0.7392
# Epoch 29/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1.4740 - accuracy: 0.7374
# Epoch 30/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1.5856 - accuracy: 0.7362
# Epoch 31/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1.7100 - accuracy: 0.7380
# Epoch 32/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1.8455 - accuracy: 0.7374
# Epoch 33/100
# 52/52 [==============================] - 0s 1ms/step - loss: -1.9962 - accuracy: 0.7386
# Epoch 34/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2.1537 - accuracy: 0.7380
# Epoch 35/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2.3083 - accuracy: 0.7374
# Epoch 36/100
# 52/52 [==============================] - 0s 1ms/step - loss: -2.5371 - accuracy: 0.7368
# Epoch 37/100
# 52/52 [==============================] - 0s 2ms/step - loss: -2.7745 - accuracy: 0.7338
# Epoch 38/100
# 52/52 [==============================] - 0s 1ms/step - loss: -3.0520 - accuracy: 0.7398
# Epoch 39/100
# 52/52 [==============================] - 0s 1ms/step - loss: -3.2601 - accuracy: 0.7380
# Epoch 40/100
# 52/52 [==============================] - 0s 1ms/step - loss: -3.5089 - accuracy: 0.7380
# Epoch 41/100
# 52/52 [==============================] - 0s 1ms/step - loss: -3.7349 - accuracy: 0.7404
# Epoch 42/100
# 52/52 [==============================] - 0s 1ms/step - loss: -4.1546 - accuracy: 0.7368
# Epoch 43/100
# 52/52 [==============================] - 0s 1ms/step - loss: -4.5394 - accuracy: 0.7386
# Epoch 44/100
# 52/52 [==============================] - 0s 1ms/step - loss: -4.8769 - accuracy: 0.7380
# Epoch 45/100
# 52/52 [==============================] - 0s 1ms/step - loss: -5.2992 - accuracy: 0.7404
# Epoch 46/100
# 52/52 [==============================] - 0s 1ms/step - loss: -5.7128 - accuracy: 0.7398
# Epoch 47/100
# 52/52 [==============================] - 0s 1ms/step - loss: -6.2259 - accuracy: 0.7368
# Epoch 48/100
# 52/52 [==============================] - 0s 1ms/step - loss: -6.8572 - accuracy: 0.7404
# Epoch 49/100
# 52/52 [==============================] - 0s 1ms/step - loss: -7.5492 - accuracy: 0.7362
# Epoch 50/100
# 52/52 [==============================] - 0s 1ms/step - loss: -8.1488 - accuracy: 0.7392
# Epoch 51/100
# 52/52 [==============================] - 0s 1ms/step - loss: -8.7730 - accuracy: 0.7368
# Epoch 52/100
# 52/52 [==============================] - 0s 2ms/step - loss: -9.3750 - accuracy: 0.7374
# Epoch 53/100
# 52/52 [==============================] - 0s 2ms/step - loss: -10.0503 - accuracy: 0.7344
# Epoch 54/100
# 52/52 [==============================] - 0s 1ms/step - loss: -10.7415 - accuracy: 0.7386
# Epoch 55/100
# 52/52 [==============================] - 0s 1ms/step - loss: -11.5456 - accuracy: 0.7398
# Epoch 56/100
# 52/52 [==============================] - 0s 1ms/step - loss: -12.3360 - accuracy: 0.7392
# Epoch 57/100
# 52/52 [==============================] - 0s 1ms/step - loss: -13.1935 - accuracy: 0.7398
# Epoch 58/100
# 52/52 [==============================] - 0s 1ms/step - loss: -14.0876 - accuracy: 0.7380
# Epoch 59/100
# 52/52 [==============================] - 0s 1ms/step - loss: -15.0507 - accuracy: 0.7356
# Epoch 60/100
# 52/52 [==============================] - 0s 1ms/step - loss: -16.0345 - accuracy: 0.7404
# Epoch 61/100
# 52/52 [==============================] - 0s 1ms/step - loss: -17.1119 - accuracy: 0.7386
# Epoch 62/100
# 52/52 [==============================] - 0s 1ms/step - loss: -18.1814 - accuracy: 0.7392
# Epoch 63/100
# 52/52 [==============================] - 0s 1ms/step - loss: -19.4237 - accuracy: 0.7368
# Epoch 64/100
# 52/52 [==============================] - 0s 1ms/step - loss: -20.6238 - accuracy: 0.7392
# Epoch 65/100
# 52/52 [==============================] - 0s 1ms/step - loss: -21.9336 - accuracy: 0.7374
# Epoch 66/100
# 52/52 [==============================] - 0s 1ms/step - loss: -23.2315 - accuracy: 0.7380
# Epoch 67/100
# 52/52 [==============================] - 0s 1ms/step - loss: -24.6416 - accuracy: 0.7374
# Epoch 68/100
# 52/52 [==============================] - 0s 1ms/step - loss: -25.9593 - accuracy: 0.7392
# Epoch 69/100
# 52/52 [==============================] - 0s 1ms/step - loss: -27.3521 - accuracy: 0.7411
# Epoch 70/100
# 52/52 [==============================] - 0s 1ms/step - loss: -28.8875 - accuracy: 0.7392
# Epoch 71/100
# 52/52 [==============================] - 0s 1ms/step - loss: -30.3274 - accuracy: 0.7380
# Epoch 72/100
# 52/52 [==============================] - 0s 1ms/step - loss: -31.9970 - accuracy: 0.7380
# Epoch 73/100
# 52/52 [==============================] - 0s 1ms/step - loss: -33.6648 - accuracy: 0.7392
# Epoch 74/100
# 52/52 [==============================] - 0s 1ms/step - loss: -35.3626 - accuracy: 0.7392
# Epoch 75/100
# 52/52 [==============================] - 0s 1ms/step - loss: -37.1371 - accuracy: 0.7404
# Epoch 76/100
# 52/52 [==============================] - 0s 1ms/step - loss: -38.9351 - accuracy: 0.7404
# Epoch 77/100
# 52/52 [==============================] - 0s 1ms/step - loss: -40.8330 - accuracy: 0.7411
# Epoch 78/100
# 52/52 [==============================] - 0s 1ms/step - loss: -42.7152 - accuracy: 0.7386
# Epoch 79/100
# 52/52 [==============================] - 0s 1ms/step - loss: -44.7897 - accuracy: 0.7380
# Epoch 80/100
# 52/52 [==============================] - 0s 1ms/step - loss: -46.8695 - accuracy: 0.7398
# Epoch 81/100
# 52/52 [==============================] - 0s 1ms/step - loss: -49.1295 - accuracy: 0.7398
# Epoch 82/100
# 52/52 [==============================] - 0s 2ms/step - loss: -51.3221 - accuracy: 0.7374
# Epoch 83/100
# 52/52 [==============================] - 0s 1ms/step - loss: -53.6614 - accuracy: 0.7392
# Epoch 84/100
# 52/52 [==============================] - 0s 1ms/step - loss: -56.1507 - accuracy: 0.7447
# Epoch 85/100
# 52/52 [==============================] - 0s 1ms/step - loss: -58.6671 - accuracy: 0.7392
# Epoch 86/100
# 52/52 [==============================] - 0s 1ms/step - loss: -61.1395 - accuracy: 0.7392
# Epoch 87/100
# 52/52 [==============================] - 0s 1ms/step - loss: -63.8807 - accuracy: 0.7392
# Epoch 88/100
# 52/52 [==============================] - 0s 1ms/step - loss: -66.6076 - accuracy: 0.7435
# Epoch 89/100
# 52/52 [==============================] - 0s 1ms/step - loss: -69.4145 - accuracy: 0.7392
# Epoch 90/100
# 52/52 [==============================] - 0s 1ms/step - loss: -72.4112 - accuracy: 0.7392
# Epoch 91/100
# 52/52 [==============================] - 0s 1ms/step - loss: -75.4643 - accuracy: 0.7392
# Epoch 92/100
# 52/52 [==============================] - 0s 1ms/step - loss: -78.5194 - accuracy: 0.7417
# Epoch 93/100
# 52/52 [==============================] - 0s 1ms/step - loss: -81.5200 - accuracy: 0.7392
# Epoch 94/100
# 52/52 [==============================] - 0s 1ms/step - loss: -84.6748 - accuracy: 0.7411
# Epoch 95/100
# 52/52 [==============================] - 0s 1ms/step - loss: -87.8080 - accuracy: 0.7374
# Epoch 96/100
# 52/52 [==============================] - 0s 1ms/step - loss: -91.0066 - accuracy: 0.7386
# Epoch 97/100
# 52/52 [==============================] - 0s 1ms/step - loss: -94.4300 - accuracy: 0.7404
# Epoch 98/100
# 52/52 [==============================] - 0s 1ms/step - loss: -97.8500 - accuracy: 0.7398
# Epoch 99/100
# 52/52 [==============================] - 0s 1ms/step - loss: -101.3252 - accuracy: 0.7398
# Epoch 100/100
# 52/52 [==============================] - 0s 1ms/step - loss: -104.8295 - accuracy: 0.7398
# 18/18 - 0s - loss: -1.1491e+02 - accuracy: 0.7636 - 120ms/epoch - 7ms/step
# Loss: -114.90711975097656, Accuracy: 0.7636363506317139
